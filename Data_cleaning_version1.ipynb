# %% [markdown]
# #### In this we will identify problems in dataset and correct them

# %%
import pandas as pd
import numpy as np

# %%
#loading the dataset
df=pd.read_csv('mobiles.csv')

# %%
#top rows of data
df.head(3)
# Out:
#                      mobile_name    price  rating  \
# 0                   OPPO Reno 11  ₹29,990    4.70
# 1                 Poco X6 Pro 5G  ₹19,999    4.50
# 2  Xiaomi Redmi Note 13 Pro Plus  ₹31,999    4.35
#
#                                         connectivity  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 2  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            processor  \
# 0       Dimensity 8200, Octa Core, 3.1 GHz Processor
# 1  Dimensity 8300 Ultra, Octa Core, 3.35 GHz Proc...
# 2  Dimensity 7200 Ultra, Octa Core, 2.8 GHz Proce...
#
#                      storage                                   battery  \
# 0   8 GB RAM, 256 GB inbuilt   4800 mAh Battery with 67W Fast Charging
# 1  12 GB RAM, 256 GB inbuilt   5500 mAh Battery with 90W Fast Charging
# 2   8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 120W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 1  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
# 2  6.67 inches, 1220 x 2712 px, 120 Hz Display wi...
#
#                                               camera  \
# 0  50 MP + 32 MP + 8 MP Triple Rear & 32 MP Front...
# 1  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 2  200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
#
#                extra_storage           os
# 0                Android v14  No FM Radio
# 1                Android v14  No FM Radio
# 2  Memory Card Not Supported  Android v13

# %%
#last rows of data
df.tail(2)
# Out:
#                  mobile_name    price  rating  \
# 2037    Motorola Moto G91 5G  ₹19,990    80.0
# 2038  Samsung Galaxy M52s 5G  ₹24,990    74.0
#
#                                  connectivity  \
# 2037  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 2038       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
#
#                                          processor                   storage  \
# 2037  Snapdragon 695, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 2038                           Octa Core Processor  8 GB RAM, 128 GB inbuilt
#
#                                   battery  \
# 2037  5000 mAh Battery with Fast Charging
# 2038  5000 mAh Battery with Fast Charging
#
#                                                 display  \
# 2037  6.8 inches, 1080 x 2400 px Display with Punch ...
# 2038  6.5 inches, 1080 x 2400 px Display with Water ...
#
#                                                  camera  \
# 2037  108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front...
# 2038  64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front ...
#
#                          extra_storage           os
# 2037  Memory Card Supported, upto 1 TB  Android v12
# 2038  Memory Card Supported, upto 1 TB  Android v12

# %%
#any two random rows of data
df.sample(2)
# Out:
#                   mobile_name    price  rating  \
# 1886       Motorola One Macro  ₹11,490   68.00
# 995   Samsung Galaxy A03 Core   ₹6,999    4.05
#
#                         connectivity  \
# 1886  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 995   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                           processor                  storage  \
# 1886          Helio P70, Octa Core, 2 GHz Processor  4 GB RAM, 64 GB inbuilt
# 995   Unisoc  SC9836A, Quad Core, 1.6 GHz Processor  2 GB RAM, 32 GB inbuilt
#
#                                       battery  \
# 1886  4000 mAh Battery with 10W Fast Charging
# 995                          5000 mAh Battery
#
#                                                 display  \
# 1886  6.2 inches, 720 x 1520 px Display with Water D...
# 995   6.5 inches, 720 x 1600 px Display with Water D...
#
#                                                  camera  \
# 1886  13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 995                       8 MP Rear & 5 MP Front Camera
#
#                           extra_storage                  os
# 1886  Memory Card (Hybrid), upto 512 GB  Android v9.0 (Pie)
# 995    Memory Card Supported, upto 1 TB         Android v10

# %%
#shape of data
df.shape
# Out:
# (2039, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2039 entries, 0 to 2038
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   mobile_name    2039 non-null   object
#  1   price          2039 non-null   object
#  2   rating         1898 non-null   float64
#  3   connectivity   2039 non-null   object
#  4   processor      2039 non-null   object
#  5   storage        2039 non-null   object
#  6   battery        2039 non-null   object
#  7   display        2039 non-null   object
#  8   camera         2038 non-null   object
#  9   extra_storage  2029 non-null   object
#  10  os             2011 non-null   object
# dtypes: float64(1), object(10)
# memory usage: 175.4+ KB

# %%
#make a copy of data before cleaning
df1=df.copy()

# %% [markdown]
# #### We will take one column at a time and clean it

# %% [markdown]
# **price**
#
# Here i notice two issues
#
# 1.rupee symbol
#
# 2.comma

# %%
df1['price']=df1['price'].str.replace('₹','').str.replace(',','').astype('int')

# %%
df1.head(1)
# Out:
#     mobile_name  price  rating  \
# 0  OPPO Reno 11  29990     4.7
#
#                                         connectivity  \
# 0  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                       processor                   storage  \
# 0  Dimensity 8200, Octa Core, 3.1 GHz Processor  8 GB RAM, 256 GB inbuilt
#
#                                    battery  \
# 0  4800 mAh Battery with 67W Fast Charging
#
#                                              display  \
# 0  6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
#
#                                               camera extra_storage  \
# 0  50 MP + 32 MP + 8 MP Triple Rear & 32 MP Front...   Android v14
#
#             os
# 0  No FM Radio

# %% [markdown]
# **There are few features phone in our dataset and some other errors so what i have observed by manual scanning that these rows have price less than 3400 so drop .**

# %%
pd.set_option('display.max_rows',None)
df1[df1['price'] < 3400]
# Out:
#                         mobile_name  price  rating  \
# 236                  Snexian Rock Z   2700    4.70
# 300                Jio Bharat B1 4G   1285    4.70
# 314               BlackZone Winx 4G   3100    4.05
# 356           JIo JioPhone Prima 4G   2599    4.55
# 359                   Jio Bharat V2    999    4.50
# 489                  Snexian Rock X   2500    4.60
# 517                    Jio JioPhone   2990    3.60
# 525           Jio Bharat K1 Karbonn    999    4.40
# 527                   iKall K333 4G   3299    4.15
# 530               Nokia 110 4G 2023   2149    4.60
# 564   Samsung Guru Music 2 Dual Sim   1659    4.50
# 579            Nokia 130 Music 2023   1749    4.20
# 604                 Itel MagicX Pro   1734    4.40
# 639               Namotel Achhe Din     99    4.00
# 647                 Snexian Bold 4G   2499    4.30
# 654                 iKall K333 Plus   3299    4.20
# 656                  Itel Power 900   1799    4.10
# 661                    Nokia 106 4G   2049    4.20
# 728                    Xiaomi Qin 1   1799    4.30
# 729                  Jio JioPhone 2   2999    3.70
# 730              Samsung Guru E1200   1299    4.30
# 739              Motorola Moto A10G   1299    4.10
# 740          Nokia 105 Classic 2023    999    4.20
# 751                  Nokia 150 2023   2599    4.75
# 793             itel MagicX Play 4G   1559    4.20
# 837                        MTR Cola   1400    4.25
# 860                       Docoss X1    888    3.65
# 863                     itel it5330   1462    4.45
# 868                      Lava A5 23   1248    4.65
# 892                     Cellecor D9   1999    4.45
# 893             Itel Super Guru 600   1749    4.20
# 894                   itel Circle 1   1499    4.60
# 902                  Nokia 105 2023   1269    4.70
# 955                    itel Magic X   1549    4.00
# 1008                Nokia 6310 2021   3199    4.25
# 1419                 Jio JioPhone 2   2999     NaN
# 1492                   Nokia 110 4G   1762     NaN
# 1551  Samsung Guru Music 2 Dual Sim   1949     NaN
# 1552                Itel MagicX Pro   2799     NaN
# 1570                itel Magic 2 4G   2399     NaN
# 1592               Nokia 105 (2019)   1299     NaN
# 1594                       Lyf C459   1999     NaN
# 1627              Namotel Achhe Din     99     NaN
# 1630                Eunity U1 5605N    699     NaN
# 1659                 Nokia 105 Plus   1299     NaN
# 1666              Motorola Moto A10   1339     NaN
# 1676                  Zanco Tiny T1   2799     NaN
# 1684                   itel it2163S    958     NaN
# 1704                   Xiaomi Qin 1   1799     NaN
# 1718          Samsung Guru GT-E1215   1850     NaN
# 1767                   Nokia 400 4G   3290     NaN
# 1776                   Karbonn KU3i    995     NaN
# 1836                   itel Magic X   2239     NaN
# 1854                 Eunity U1 King    599     NaN
# 1865                  DIZO Star 500   1749     NaN
# 1871                   Nokia 215 4G   3099     NaN
# 1892             BlackZone Ultra 4G   1899     NaN
# 1900               Nokia 110 (2022)   1599     NaN
# 1936               Nokia 150 (2020)   2499     NaN
# 1946             Samsung Guru E1200   1685     NaN
# 1949               iKall K88 Pro 4G   2099     NaN
# 1951                 Eunity U1 Livo    649     NaN
# 2007            Nokia 5310 Dual Sim   3399     NaN
# 2019                XTouch F40 Flip   1999     NaN
#
#                           connectivity  \
# 236                           Dual Sim
# 300          Single Sim, 3G, 4G, VoLTE
# 314     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 356       Single Sim, 4G, VoLTE, Wi-Fi
# 359          Single Sim, 3G, 4G, VoLTE
# 489                           Dual Sim
# 517   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 525          Single Sim, 3G, 4G, VoLTE
# 527            Dual Sim, 3G, 4G, VoLTE
# 530            Dual Sim, 3G, 4G, VoLTE
# 564                           Dual Sim
# 579                           Dual Sim
# 604     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 639                Dual Sim, 3G, Wi-Fi
# 647                       Dual Sim, 4G
# 654            Dual Sim, 3G, 4G, VoLTE
# 656                           Dual Sim
# 661            Dual Sim, 3G, 4G, VoLTE
# 728                    Dual Sim, Wi-Fi
# 729     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 730                         Single Sim
# 739                       Dual Sim, 3G
# 740                         Single Sim
# 751                           Dual Sim
# 793     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 837                           Dual Sim
# 860                Dual Sim, 3G, Wi-Fi
# 863                           Dual Sim
# 868                           Dual Sim
# 892                           Dual Sim
# 893                           Dual Sim
# 894                           Dual Sim
# 902                         Single Sim
# 955     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1008                   Dual Sim, Wi-Fi
# 1419    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1492           Dual Sim, 3G, 4G, VoLTE
# 1551                          Dual Sim
# 1552    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1570    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1592                        Single Sim
# 1594    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1627               Dual Sim, 3G, Wi-Fi
# 1630                          Dual Sim
# 1659                          Dual Sim
# 1666                          Dual Sim
# 1676                        Single Sim
# 1684                          Dual Sim
# 1704                   Dual Sim, Wi-Fi
# 1718                        Single Sim
# 1767        Dual Sim, 4G, VoLTE, Wi-Fi
# 1776                          Dual Sim
# 1836    Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1854                          Dual Sim
# 1865                          Dual Sim
# 1871           Dual Sim, 3G, 4G, VoLTE
# 1892           Dual Sim, 3G, 4G, VoLTE
# 1900                          Dual Sim
# 1936                          Dual Sim
# 1946                        Single Sim
# 1949           Dual Sim, 3G, 4G, VoLTE
# 1951                          Dual Sim
# 2007                          Dual Sim
# 2019                          Dual Sim
#
#                                              processor  \
# 236                           32 MB RAM, 32 MB inbuilt
# 300                                            No Wifi
# 314                         Quad Core, 1 GHz Processor
# 356                           512 MB RAM, 4 GB inbuilt
# 359                                            No Wifi
# 489                           32 MB RAM, 32 MB inbuilt
# 517               QC8905, Dual Core, 1.2 GHz Processor
# 525                                            No Wifi
# 527                                       Helio MT6739
# 530                                            No Wifi
# 564                                            No Wifi
# 579                                            No Wifi
# 604                                    1 GHz Processor
# 639                             1 GB RAM, 4 GB inbuilt
# 647                                Quad Core Processor
# 654                       Quad Core, 1.3 GHz Processor
# 656           10000 mAh Battery with 10W Fast Charging
# 661                                            No Wifi
# 728                                      Helio MT6260A
# 729                         Dual Core, 1 GHz Processor
# 730                                            No Wifi
# 739                                  1.5 MHz Processor
# 740                             4 MB RAM, 4 MB inbuilt
# 751                                            No Wifi
# 793                                              No 3G
# 837                           32 MB RAM, 32 GB inbuilt
# 860                       Quad Core, 1.2 GHz Processor
# 863                           32 MB RAM, 32 MB inbuilt
# 868                           32 MB RAM, 24 MB inbuilt
# 892                                  100 kHz Processor
# 893                         SC6531C, 312 MHz Processor
# 894                                    1 MHz Processor
# 902                                            No Wifi
# 955                                              No 3G
# 1008                                     Unisoc  6531F
# 1419                        Dual Core, 1 GHz Processor
# 1492                                           No Wifi
# 1551                                           No Wifi
# 1552                                   1 GHz Processor
# 1570                                             No 3G
# 1592                                           No Wifi
# 1594  Snapdragon MSM8909, Quad Core, 1.1 GHz Processor
# 1627                            1 GB RAM, 4 GB inbuilt
# 1630                                             No 3G
# 1659                            4 MB RAM, 4 MB inbuilt
# 1666                            4 MB RAM, 4 MB inbuilt
# 1676                          32 MB RAM, 32 MB inbuilt
# 1684                            4 MB RAM, 4 MB inbuilt
# 1704                                     Helio MT6260A
# 1718                                   800 mAh Battery
# 1767                                  2000 mAh Battery
# 1776                          52 MB RAM, 32 MB inbuilt
# 1836                                             No 3G
# 1854                                1.77 MHz Processor
# 1865                         SC6531E, 26 MHz Processor
# 1871                                       Unisoc T117
# 1892                      Single Core, 1 GHz Processor
# 1900                                           No Wifi
# 1936                                           No Wifi
# 1946                                           No Wifi
# 1949                         48 MB RAM, 128 MB inbuilt
# 1951                                1.77 MHz Processor
# 2007                           8 MB RAM, 16 MB inbuilt
# 2019                                             No 3G
#
#                                storage                              battery  \
# 236                   3000 mAh Battery     2.4 inches, 128 x 160 px Display
# 300           512 MB RAM, 4 GB inbuilt                     2000 mAh Battery
# 314            2 GB RAM, 16 GB inbuilt  3000 mAh Battery with Fast Charging
# 356                   1800 mAh Battery     2.4 inches, 240 x 320 px Display
# 359           512 MB RAM, 4 GB inbuilt                     1000 mAh Battery
# 489                   3000 mAh Battery     1.8 inches, 240 x 320 px Display
# 517           512 MB RAM, 4 GB inbuilt                     2000 mAh Battery
# 525                                ASR             512 MB RAM, 4 GB inbuilt
# 527            2 GB RAM, 16 GB inbuilt                     3000 mAh Battery
# 530          128 MB RAM, 48 MB inbuilt                     1450 mAh Battery
# 564     Single Core, 208 MHz Processor                      800 mAh Battery
# 579             4 MB RAM, 4 MB inbuilt                     1450 mAh Battery
# 604          64 MB RAM, 128 MB inbuilt                     2500 mAh Battery
# 639                   1325 mAh Battery      4 inches, 720 x 1280 px Display
# 647            2 GB RAM, 16 GB inbuilt                     3000 mAh Battery
# 654            2 GB RAM, 16 GB inbuilt                     3000 mAh Battery
# 656   2.8 inches, 240 x 320 px Display                   0.3 MP Rear Camera
# 661                           4 MB RAM                     1450 mAh Battery
# 728            8 MB RAM, 16 MB inbuilt                     1480 mAh Battery
# 729           512 MB RAM, 4 GB inbuilt                     2000 mAh Battery
# 730                    800 mAh Battery     1.5 inches, 128 x 128 px Display
# 739            4 MB RAM, 32 MB inbuilt                      800 mAh Battery
# 740                    800 mAh Battery    1.77 inches, 128 x 160 px Display
# 751             4 MB RAM, 4 MB inbuilt                     1450 mAh Battery
# 793          48 MB RAM, 128 MB inbuilt                     1900 mAh Battery
# 837                    800 mAh Battery                     1 inches Display
# 860             1 GB RAM, 4 GB inbuilt                     1300 mAh Battery
# 863                   1900 mAh Battery     2.8 inches, 320 x 240 px Display
# 868                   1000 mAh Battery     2.4 inches, 240 x 320 px Display
# 892           32 MB RAM, 32 MB inbuilt                     2000 mAh Battery
# 893                      32 MB inbuilt                     1900 mAh Battery
# 894           32 MB RAM, 32 MB inbuilt                      500 mAh Battery
# 902             4 MB RAM, 4 MB inbuilt                     1000 mAh Battery
# 955                               T117            48 MB RAM, 128 MB inbuilt
# 1008           8 MB RAM, 16 MB inbuilt                     1150 mAh Battery
# 1419          512 MB RAM, 4 GB inbuilt                     2000 mAh Battery
# 1492         128 MB RAM, 48 MB inbuilt                     1020 mAh Battery
# 1551    Single Core, 208 MHz Processor                      800 mAh Battery
# 1552         64 MB RAM, 128 MB inbuilt                     2500 mAh Battery
# 1570                              T117            64 MB RAM, 128 MB inbuilt
# 1592            4 MB RAM, 4 MB inbuilt                      800 mAh Battery
# 1594            1 GB RAM, 8 GB inbuilt                     2000 mAh Battery
# 1627                  1325 mAh Battery      4 inches, 720 x 1280 px Display
# 1630      Dual Core, 500 MHz Processor             32 MB RAM, 32 MB inbuilt
# 1659                   800 mAh Battery    1.77 inches, 128 x 160 px Display
# 1666                  1750 mAh Battery     1.8 inches, 160 x 128 px Display
# 1676                   200 mAh Battery      0.49 inches, 64 x 32 px Display
# 1684                  1200 mAh Battery     1.8 inches, 160 x 128 px Display
# 1704           8 MB RAM, 16 MB inbuilt                     1480 mAh Battery
# 1718  1.5 inches, 120 x 120 px Display                       No Rear Camera
# 1767  2.4 inches, 240 x 320 px Display    0.3 MP Rear & 0.3 MP Front Camera
# 1776                  1000 mAh Battery     1.8 inches, 128 x 160 px Display
# 1836                              T117            48 MB RAM, 128 MB inbuilt
# 1854          32 MB RAM, 32 MB inbuilt                     1000 mAh Battery
# 1865          32 MB RAM, 32 MB inbuilt                     1900 mAh Battery
# 1871         64 MB RAM, 128 MB inbuilt                     1150 mAh Battery
# 1892          48 MB RAM, 48 MB inbuilt                     2500 mAh Battery
# 1900            4 MB RAM, 4 MB inbuilt                     1000 mAh Battery
# 1936                      4 MB inbuilt                     1020 mAh Battery
# 1946                   800 mAh Battery     1.5 inches, 128 x 128 px Display
# 1949                  1800 mAh Battery     2.4 inches, 240 x 360 px Display
# 1951          16 MB RAM, 16 MB inbuilt                     1000 mAh Battery
# 2007                  1200 mAh Battery     2.4 inches, 240 x 320 px Display
# 2019                           No Wifi             32 MB RAM, 32 MB inbuilt
#
#                                 display                              camera  \
# 236                  0.3 MP Rear Camera    Memory Card (Hybrid), upto 16 GB
# 300    2.4 inches, 240 x 320 px Display                  0.3 MP Rear Camera
# 314    2.8 inches, 480 x 640 px Display       5 MP Rear & 2 MP Front Camera
# 356   0.3 MP Rear & 0.3 MP Front Camera  Memory Card Supported, upto 128 GB
# 359   1.77 inches, 240 x 320 px Display                  0.3 MP Rear Camera
# 489                  0.3 MP Rear Camera    Memory Card (Hybrid), upto 16 GB
# 517    2.4 inches, 240 x 320 px Display     2 MP Rear & 0.3 MP Front Camera
# 525                    1000 mAh Battery   1.77 inches, 240 x 320 px Display
# 527    2.8 inches, 240 x 360 px Display       2 MP Rear & 2 MP Front Camera
# 530    1.8 inches, 120 x 160 px Display                  0.3 MP Rear Camera
# 564      2 inches, 128 x 160 px Display                      No Rear Camera
# 579    2.4 inches, 240 x 320 px Display                      No Rear Camera
# 604    2.4 inches, 320 x 240 px Display                  0.3 MP Rear Camera
# 639     2 MP Rear & 0.3 MP Front Camera             Android v5.0 (Lollipop)
# 647    2.8 inches, 240 x 320 px Display                  1.3 MP Rear Camera
# 654    2.8 inches, 240 x 360 px Display       2 MP Rear & 2 MP Front Camera
# 656   Memory Card Supported, upto 32 GB                           Bluetooth
# 661    1.8 inches, 120 x 160 px Display                      No Rear Camera
# 728    2.8 inches, 240 x 320 px Display                      No Rear Camera
# 729    2.4 inches, 320 x 240 px Display     2 MP Rear & 0.3 MP Front Camera
# 730                      No Rear Camera                         No FM Radio
# 739    1.8 inches, 160 x 128 px Display                      No Rear Camera
# 740                      No Rear Camera                                S30+
# 751    2.4 inches, 240 x 320 px Display   Memory Card Supported, upto 32 GB
# 793    1.8 inches, 128 x 160 px Display                  0.3 MP Rear Camera
# 837                  0.3 MP Rear Camera    Memory Card Supported, upto 8 GB
# 860      4 inches, 480 x 854 px Display     2 MP Rear & 0.3 MP Front Camera
# 863                  0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 868                  0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 892    2.8 inches, 240 x 320 px Display                  0.8 MP Rear Camera
# 893                  2.8 inches Display                  1.3 MP Rear Camera
# 894   1.32 inches, 240 x 240 px Display                  0.3 MP Rear Camera
# 902    1.8 inches, 120 x 160 px Display                      No Rear Camera
# 955                    1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 1008   2.8 inches, 160 x 240 px Display                  0.3 MP Rear Camera
# 1419   2.4 inches, 320 x 240 px Display     2 MP Rear & 0.3 MP Front Camera
# 1492   1.8 inches, 120 x 160 px Display                  0.3 MP Rear Camera
# 1551     2 inches, 128 x 160 px Display                      No Rear Camera
# 1552   2.4 inches, 320 x 240 px Display                  0.3 MP Rear Camera
# 1570                   1900 mAh Battery    2.4 inches, 240 x 320 px Display
# 1592  1.77 inches, 120 x 160 px Display                      No Rear Camera
# 1594   4.5 inches, 480 x 854 px Display       5 MP Rear & 2 MP Front Camera
# 1627    2 MP Rear & 0.3 MP Front Camera             Android v5.0 (Lollipop)
# 1630                   3000 mAh Battery    1.8 inches, 128 x 160 px Display
# 1659                     No Rear Camera   Memory Card Supported, upto 32 GB
# 1666                     No Rear Camera   Memory Card Supported, upto 32 GB
# 1676                     No Rear Camera                         No FM Radio
# 1684                     No Rear Camera   Memory Card Supported, upto 32 GB
# 1704   2.8 inches, 240 x 320 px Display                      No Rear Camera
# 1718                        No FM Radio                                 NaN
# 1767  Memory Card Supported, upto 64 GB                           Bluetooth
# 1776                     No Rear Camera   Memory Card Supported, upto 16 GB
# 1836                   1200 mAh Battery    2.4 inches, 240 x 320 px Display
# 1854   1.8 inches, 260 x 240 px Display                  0.3 MP Rear Camera
# 1865   2.8 inches, 240 x 320 px Display                  0.3 MP Rear Camera
# 1871   2.4 inches, 240 x 320 px Display                      No Rear Camera
# 1892   1.8 inches, 480 x 640 px Display                    2 MP Rear Camera
# 1900  1.77 inches, 120 x 160 px Display   Memory Card Supported, upto 32 GB
# 1936   2.4 inches, 240 x 320 px Display                  0.3 MP Rear Camera
# 1946                     No Rear Camera                         No FM Radio
# 1949                 0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 1951   1.8 inches, 280 x 240 px Display                  0.3 MP Rear Camera
# 2007                 0.3 MP Rear Camera   Memory Card Supported, upto 32 GB
# 2019                    800 mAh Battery   1.77 inches, 240 x 320 px Display
#
#                            extra_storage                                  os
# 236                         Symbian v9.1                           Bluetooth
# 300   Memory Card Supported, upto 128 GB                           Bluetooth
# 314    Memory Card Supported, upto 64 GB                       Android v11.0
# 356                         KaiOS v2.5.3                           Bluetooth
# 359   Memory Card Supported, upto 128 GB                           Bluetooth
# 489                            Bluetooth                                 NaN
# 517   Memory Card Supported, upto 128 GB                           Bluetooth
# 525                   0.3 MP Rear Camera  Memory Card Supported, upto 128 GB
# 527   Memory Card Supported, upto 128 GB                         Android v12
# 530    Memory Card Supported, upto 32 GB                           Bluetooth
# 564    Memory Card Supported, upto 16 GB                                 NaN
# 579    Memory Card Supported, upto 32 GB                                 v30
# 604    Memory Card Supported, upto 64 GB                           Bluetooth
# 639                            Bluetooth                                 NaN
# 647                                 v1.7                                 NaN
# 654   Memory Card Supported, upto 128 GB                         Android v12
# 656                                  NaN                                 NaN
# 661    Memory Card Supported, upto 32 GB                           Bluetooth
# 728                              Nucleus                         No FM Radio
# 729   Memory Card Supported, upto 128 GB                              KAI OS
# 730                                  NaN                                 NaN
# 739    Memory Card Supported, upto 64 GB                           Bluetooth
# 740                                  NaN                                 NaN
# 751                                  v30                                 NaN
# 793    Memory Card Supported, upto 64 GB                               Mocor
# 837                          No FM Radio                           Bluetooth
# 860    Memory Card Supported, upto 32 GB               Android v4.4 (KitKat)
# 863                            Bluetooth                                 NaN
# 868                            Bluetooth                                 NaN
# 892    Memory Card Supported, upto 32 GB                        Symbian v9.1
# 893                           Nucleus OS                           Bluetooth
# 894    Memory Card Supported, upto 32 GB                           Bluetooth
# 902                Memory Card Supported                                 NaN
# 955                   1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 1008   Memory Card Supported, upto 32 GB                           Bluetooth
# 1419  Memory Card Supported, upto 128 GB                              KAI OS
# 1492   Memory Card Supported, upto 32 GB                                 NaN
# 1551   Memory Card Supported, upto 16 GB                                 NaN
# 1552   Memory Card Supported, upto 64 GB                           Bluetooth
# 1570                  1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 1592                                 NaN                                 NaN
# 1594   Memory Card Supported, upto 32 GB          Android v6.0 (Marshmallow)
# 1627                           Bluetooth                                 NaN
# 1630                  0.3 MP Rear Camera   Memory Card Supported, upto 16 GB
# 1659                           Bluetooth                                 NaN
# 1666                                 NaN                                 NaN
# 1676                           Bluetooth                                 NaN
# 1684                           Bluetooth                                 NaN
# 1704                             Nucleus                         No FM Radio
# 1718                                 NaN                                 NaN
# 1767                             Browser                                 NaN
# 1776                           Bluetooth                                 NaN
# 1836                  1.3 MP Rear Camera   Memory Card Supported, upto 64 GB
# 1854                                 NaN                                 NaN
# 1865   Memory Card Supported, upto 64 GB                           Bluetooth
# 1871   Memory Card Supported, upto 32 GB                   RTOS (Series 30+)
# 1892   Memory Card Supported, upto 48 GB                           Bluetooth
# 1900                                 NaN                                 NaN
# 1936   Memory Card Supported, upto 32 GB                           Bluetooth
# 1946                                 NaN                                 NaN
# 1949                           Bluetooth                             Browser
# 1951                                 NaN                                 NaN
# 2007                           Bluetooth                             Browser
# 2019                        Dual Display                  1.3 MP Rear Camera

# %%
df1=df1[df1['price'] > 3400]

# %%
df1.shape
# Out:
# (1975, 11)

# %%
#we will remove those rows which has incorrect value in processor column
words = ['Bionic', 'processor', 'apple', 'snapdragon']
pattern = '|'.join(words)  # regex OR
df1=df1[df1['processor'].str.contains(pattern, case=False, na=False)]

# %%
df1.shape
# Out:
# (1963, 11)

# %%
df1['storage'].value_counts()
# Out:
# storage
# 8 GB RAM, 128 GB inbuilt     525
# 6 GB RAM, 128 GB inbuilt     330
# 12 GB RAM, 256 GB inbuilt    236
# 4 GB RAM, 64 GB inbuilt      232
# 8 GB RAM, 256 GB inbuilt     204
# 4 GB RAM, 128 GB inbuilt     124
# 3 GB RAM, 32 GB inbuilt       46
# 6 GB RAM, 64 GB inbuilt       41
# 12 GB RAM, 512 GB inbuilt     33
# 2 GB RAM, 32 GB inbuilt       30
# 16 GB RAM, 256 GB inbuilt     26
# 3 GB RAM, 64 GB inbuilt       22
# 6 GB RAM, 256 GB inbuilt      12
# 12 GB RAM, 128 GB inbuilt     10
# 1 GB RAM, 16 GB inbuilt       10
# 16 GB RAM, 512 GB inbuilt     10
# 2 GB RAM, 64 GB inbuilt        9
# 4 GB RAM, 32 GB inbuilt        9
# 6 GB RAM, 512 GB inbuilt       6
# 2 GB RAM, 16 GB inbuilt        5
# 6 GB RAM, 1 TB inbuilt         5
# 8 GB RAM, 512 GB inbuilt       5
# 4 GB RAM, 256 GB inbuilt       5
# 18 GB RAM, 512 GB inbuilt      4
# 512 MB RAM, 4 GB inbuilt       4
# 64 GB inbuilt                  3
# 12 GB RAM, 1 TB inbuilt        3
# 4 GB RAM, 512 MB inbuilt       2
# 8 GB RAM, 1 TB inbuilt         2
# 24 GB RAM, 1 TB inbuilt        2
# 4 GB RAM, 512 GB inbuilt       2
# 3 GB RAM, 16 GB inbuilt        2
# 256 GB inbuilt                 1
# 18 GB RAM, 256 GB inbuilt      1
# 512 GB inbuilt                 1
# 1 GB RAM, 8 GB inbuilt         1
# Name: count, dtype: int64

# %% [markdown]
# **These are the rows that dont have ram info so we will handle this later .other than this there is no problem in storage column**

# %%
df1[~df1['storage'].str.contains(',', case=False, na=False)]
# Out:
#                            mobile_name   price  rating  \
# 217                     Huawei P60 Pro   83999    4.70
# 325                  Apple iPhone SE 4   49990    4.15
# 1458            Apple iPhone SE 3 2022   43900     NaN
# 1502  Huawei Mate 50 RS Porsche Design  239999   81.00
# 1781                 Apple iPhone SE 4   49990   60.00
#
#                                          connectivity  \
# 217   Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 325           Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1458          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1502  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 1781          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                               processor         storage  \
# 217   Snapdragon 8+ Gen 1 , Octa Core, 3.19 GHz Proc...  256 GB inbuilt
# 325           Bionic A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 1458         Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 1502   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 1781         Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
#
#                                       battery  \
# 217   4815 mAh Battery with 88W Fast Charging
# 325         6.1 inches, 750 x 1580 px Display
# 1458        4.7 inches, 750 x 1334 px Display
# 1502  4700 mAh Battery with 66W Fast Charging
# 1781        6.1 inches, 750 x 1580 px Display
#
#                                                 display  \
# 217   6.67 inches, 1220 x 2700 px, 120 Hz Display wi...
# 325                   12 MP Rear & 10.8 MP Front Camera
# 1458                     12 MP Rear & 7 MP Front Camera
# 1502        6.74 inches, 1212 x 2616 px, 120 Hz Display
# 1781                  12 MP Rear & 10.8 MP Front Camera
#
#                                                  camera  \
# 217   48 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 325                           Memory Card Not Supported
# 1458                          Memory Card Not Supported
# 1502  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 1781                          Memory Card Not Supported
#
#                           extra_storage                os
# 217                Memory Card (Hybrid)    HarmonyOS v3.1
# 325                             iOS v16       No FM Radio
# 1458                            iOS v15       No FM Radio
# 1502  Memory Card (Hybrid), upto 256 GB  Hongmeng OS v3.0
# 1781                            iOS v16       No FM Radio

# %% [markdown]
# **Problem in battery column is basically that because battery info is not available for some iphones so rows has shifted towarda left**

# %%
temp_df=df1[~df1['battery'].str.contains('mAh', case=False, na=False)]
temp_df.iloc[:,6:]
# Out:
#                                                 battery  \
# 176   6.1 inches, 1170 x 2532 px Display with Large ...
# 325                   6.1 inches, 750 x 1580 px Display
# 486   6.1 inches, 1170 x 2532 px Display with Large ...
# 1130  6.1 inches, 1170 x 2532 px Display with Large ...
# 1168                 5.4 inches, 1080 x 2340 px Display
# 1326  6.1 inches, 1170 x 2532 px Display with Large ...
# 1382                 5.4 inches, 1080 x 2340 px Display
# 1458                  4.7 inches, 750 x 1334 px Display
# 1467  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 1647  6.1 inches, 1170 x 2532 px Display with Large ...
# 1781                  6.1 inches, 750 x 1580 px Display
# 1872  6.1 inches, 1170 x 2532 px Display with Large ...
# 1932                 5.4 inches, 1080 x 2340 px Display
# 1933  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                 display  \
# 176        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 325                   12 MP Rear & 10.8 MP Front Camera
# 486        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1130       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1168       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1326       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1382       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1458                     12 MP Rear & 7 MP Front Camera
# 1467  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 1647  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 1781                  12 MP Rear & 10.8 MP Front Camera
# 1872  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 1932       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1933       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                          camera extra_storage           os
# 176   Memory Card Not Supported       iOS v14  No FM Radio
# 325   Memory Card Not Supported       iOS v16  No FM Radio
# 486   Memory Card Not Supported       iOS v14  No FM Radio
# 1130  Memory Card Not Supported       iOS v14  No FM Radio
# 1168  Memory Card Not Supported       iOS v14  No FM Radio
# 1326  Memory Card Not Supported       iOS v14  No FM Radio
# 1382  Memory Card Not Supported       iOS v14  No FM Radio
# 1458  Memory Card Not Supported       iOS v15  No FM Radio
# 1467  Memory Card Not Supported       iOS v15  No FM Radio
# 1647  Memory Card Not Supported     iOS v14.0  No FM Radio
# 1781  Memory Card Not Supported       iOS v16  No FM Radio
# 1872  Memory Card Not Supported     iOS v14.0  No FM Radio
# 1932  Memory Card Not Supported       iOS v14  No FM Radio
# 1933  Memory Card Not Supported       iOS v14  No FM Radio

# %%
x=temp_df.iloc[:,6:].shift(1,axis=1).values
x
# Out:
# array([[None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '6.1 inches, 750\u2009x\u20091580\u2009px Display',
#         '12\u2009MP Rear & 10.8\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v16'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None, '4.7 inches, 750\u2009x\u20091334\u2009px Display',
#         '12\u2009MP Rear & 7\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
#        [None,
#         '6.06 inches, 1170\u2009x\u20092532\u2009px, 120 Hz Display with Punch Hole',
#         '50\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v15'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14.0'],
#        [None, '6.1 inches, 750\u2009x\u20091580\u2009px Display',
#         '12\u2009MP Rear & 10.8\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v16'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP + 12\u2009MP Triple Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14.0'],
#        [None, '5.4 inches, 1080\u2009x\u20092340\u2009px Display',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14'],
#        [None,
#         '6.1 inches, 1170\u2009x\u20092532\u2009px Display with Large Notch',
#         '12\u2009MP + 12\u2009MP Dual Rear & 12\u2009MP Front Camera',
#         'Memory Card Not Supported', 'iOS v14']], dtype=object)

# %%
df1.loc[temp_df.index,temp_df.columns[6:]]=x

# %% [markdown]
# So here basically we have correct the arrangement of these rows using shift function
# now we will update our dataset

# %%
df1[~df1['battery'].str.contains('mAh', case=False, na=False)]
#here we have solved that shifted problem
# Out:
#                        mobile_name   price  rating  \
# 176                Apple iPhone 12   42999    4.55
# 325              Apple iPhone SE 4   49990    4.15
# 486        Apple iPhone 12 (128GB)   48999    4.55
# 1130               Apple iPhone 12   51999   74.00
# 1168          Apple iPhone 12 Mini   40999   74.00
# 1326       Apple iPhone 12 (128GB)   55999   75.00
# 1382  Apple iPhone 12 Mini (128GB)   45999   75.00
# 1458        Apple iPhone SE 3 2022   43900     NaN
# 1467           Apple iPhone 15 Pro  130990   75.00
# 1647   Apple iPhone 12 Pro (512GB)  139900   80.00
# 1781             Apple iPhone SE 4   49990   60.00
# 1872   Apple iPhone 12 Pro (256GB)  119900   80.00
# 1932  Apple iPhone 12 Mini (256GB)   55999   75.00
# 1933       Apple iPhone 12 (256GB)   67999   76.00
#
#                                  connectivity  \
# 176   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 325   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 486   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1130  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1168  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1326  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1382  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1458  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1467  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1647  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1781  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1872  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1932  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1933  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                        processor                   storage  \
# 176     Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 325    Bionic A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 486     Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 1130    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 1168    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 1326    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 1382    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 1458  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 1467                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 1647    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 1781  Bionic  A15, Hexa Core, 3.22 GHz Processor             64 GB inbuilt
# 1872    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 1932    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 1933    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#      battery                                            display  \
# 176     None  6.1 inches, 1170 x 2532 px Display with Large ...
# 325     None                  6.1 inches, 750 x 1580 px Display
# 486     None  6.1 inches, 1170 x 2532 px Display with Large ...
# 1130    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 1168    None                 5.4 inches, 1080 x 2340 px Display
# 1326    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 1382    None                 5.4 inches, 1080 x 2340 px Display
# 1458    None                  4.7 inches, 750 x 1334 px Display
# 1467    None  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 1647    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 1781    None                  6.1 inches, 750 x 1580 px Display
# 1872    None  6.1 inches, 1170 x 2532 px Display with Large ...
# 1932    None                 5.4 inches, 1080 x 2340 px Display
# 1933    None  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                  camera  \
# 176        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 325                   12 MP Rear & 10.8 MP Front Camera
# 486        12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1130       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1168       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1326       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1382       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1458                     12 MP Rear & 7 MP Front Camera
# 1467  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 1647  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 1781                  12 MP Rear & 10.8 MP Front Camera
# 1872  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 1932       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 1933       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                   extra_storage         os
# 176   Memory Card Not Supported    iOS v14
# 325   Memory Card Not Supported    iOS v16
# 486   Memory Card Not Supported    iOS v14
# 1130  Memory Card Not Supported    iOS v14
# 1168  Memory Card Not Supported    iOS v14
# 1326  Memory Card Not Supported    iOS v14
# 1382  Memory Card Not Supported    iOS v14
# 1458  Memory Card Not Supported    iOS v15
# 1467  Memory Card Not Supported    iOS v15
# 1647  Memory Card Not Supported  iOS v14.0
# 1781  Memory Card Not Supported    iOS v16
# 1872  Memory Card Not Supported  iOS v14.0
# 1932  Memory Card Not Supported    iOS v14
# 1933  Memory Card Not Supported    iOS v14

# %%
df1['display'].value_counts()
# Out:
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          113
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            61
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch               55
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           36
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch              34
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            34
# 6.51 inches, 720 x 1600 px Display with Water Drop Notch              31
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             30
# 6.43 inches, 1080 x 2400 px Display with Punch Hole                   23
# 6.62 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           23
# 6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           22
# 6.4 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             21
# 6.7 inches, 1440 x 3216 px, 120 Hz Display with Punch Hole            21
# 6.7 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            21
# 6.56 inches, 720 x 1612 px, 90 Hz Display with Water Drop Notch       20
# 6.5 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            19
# 6.72 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           19
# 6.78 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole           19
# 6.78 inches, 1260 x 2800 px, 120 Hz Display with Punch Hole           17
# 6.56 inches, 720 x 1612 px Display with Water Drop Notch              17
# 6.58 inches, 1080 x 2408 px Display with Water Drop Notch             15
# 6.6 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             15
# 6.6 inches, 1080 x 2408 px Display with Water Drop Notch              15
# 6.53 inches, 720 x 1600 px Display with Water Drop Notch              15
# 6.6 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch       14
# 6.5 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        14
# 6.6 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch      14
# 6.55 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            14
# 6.58 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch     13
# 6.5 inches, 720 x 1600 px, 90 Hz Display with Punch Hole              13
# 6.58 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch      13
# 6.67 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole           12
# 6.58 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch      11
# 6.67 inches, 1220 x 2712 px, 120 Hz Display with Punch Hole           11
# 6.67 inches, 1080 x 2400 px Display with Punch Hole                   11
# 6.7 inches, 1080 x 2400 px Display with Punch Hole                    11
# 6.8 inches, 1116 x 2480 px, 120 Hz Display                            11
# 6.1 inches, 1170 x 2532 px Display with Small Notch                   11
# 6.74 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch       11
# 6.59 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole           10
# 6.79 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole            10
# 6.6 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            10
# 6.74 inches, 1240 x 2772 px, 120 Hz Display with Punch Hole           10
# 6.78 inches, 1080 x 2448 px, 165 Hz Display                            9
# 6.4 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole             9
# 6.73 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            9
# 6.78 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            9
# 6.44 inches, 1080 x 2400 px Display with Water Drop Notch              9
# 6.67 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            9
# 6.7 inches, 720 x 1600 px Display with Water Drop Notch                9
# 6.8 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole             9
# 6.72 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             8
# 6.67 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole            8
# 6.74 inches, 1240 x 2772 px, 144 Hz Display with Punch Hole            8
# 6.6 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole             8
# 6.53 inches, 1080 x 2340 px Display with Water Drop Notch              8
# 6.6 inches, 720 x 1612 px Display with Water Drop Notch                8
# 6.71 inches, 720 x 1650 px Display with Water Drop Notch               7
# 6.6 inches, 720 x 1612 px, 90 Hz Display with Water Drop Notch         7
# 6.6 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole             7
# 6.1 inches, 1170 x 2532 px Display with Large Notch                    7
# 6.5 inches, 1080 x 2340 px, 120 Hz Display with Water Drop Notch       7
# 6.4 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch        7
# 6.56 inches, 1080 x 2376 px, 120 Hz Display with Punch Hole            7
# 6.78 inches, 1440 x 3200 px, 144 Hz Display with Punch Hole            7
# 6.7 inches, 1080 x 2400 px Display with Water Drop Notch               7
# 6.4 inches, 1080 x 2400 px Display with Punch Hole                     7
# 6.6 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole             6
# 7.6 inches, 1812 x 2176 px, 120 Hz Display with Punch Hole             6
# 6.5 inches, 1600 x 720 px Display with Water Drop Notch                6
# 6.8 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole             6
# 6.8 inches, 1440 x 3080 px, 120 Hz Display with Punch Hole             6
# 6.43 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            6
# 6.5 inches, 720 x 1560 px Display with Water Drop Notch                6
# 6.67 inches, 2400 x 1080 px, 120 Hz Display with Punch Hole            6
# 6.1 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole             6
# 6.44 inches, 1080 x 2404 px, 90 Hz Display with Water Drop Notch       6
# 6.67 inches, 1080 x 2408 px, 120 Hz Display with Water Drop Notch      6
# 6.78 inches, 1260 x 2800 px, 144 Hz Display with Punch Hole            6
# 6.73 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            5
# 6.67 inches, 1220 x 2712 px, 144 Hz Display with Punch Hole            5
# 6.58 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            5
# 6.56 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            5
# 6.6 inches, 2408 x 1080 px Display with Water Drop Notch               5
# 6.7 inches, 1080 x 2640 px, 120 Hz Display with Punch Hole             5
# 6.6 inches, 1080 x 2408 px, 90 Hz Display with Punch Hole              5
# 6.47 inches, 1080 x 2400 px Display with Punch Hole                    5
# 6.4 inches, 1080 x 2340 px Display with Water Drop Notch               5
# 6.55 inches, 720 x 1612 px Display with Water Drop Notch               5
# 6.5 inches, 1080 x 2340 px, 90 Hz Display with Water Drop Notch        5
# 6.6 inches, 2460 x 1080 px, 90 Hz Display with Punch Hole              5
# 6.7 inches, 1284 x 2778 px Display with Small Notch                    5
# 6.44 inches, 1080 x 2408 px Display with Water Drop Notch              5
# 8.03 inches, 1916 x 2160 px, 120 Hz Display                            5
# 6.7 inches, 1080 x 2388 px, 90 Hz Display with Punch Hole              4
# 7.1 inches, 1792 x 1920 px, 120 Hz Display with Punch Hole             4
# 6.56 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        4
# 6.8 inches, 1080 x 2460 px Display with Punch Hole                     4
# 6.4 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole             4
# 6.35 inches, 720 x 1544 px Display with Water Drop Notch               4
# 6.64 inches, 1080 x 2388 px, 120 Hz Display with Punch Hole            4
# 6.71 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            4
# 6.6 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch         4
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch       4
# 6.6 inches, 1080 x 2400 px Display with Water Drop Notch               4
# 6.44 inches, 1080 x 2408 px, 90 Hz Display with Water Drop Notch       4
# 6.5 inches, 1644 x 3840 px, 120 Hz Display                             4
# 4.7 inches, 750 x 1334 px Display                                      4
# 6.7 inches, 1284 x 2778 px, 120 Hz Display with Small Notch            4
# 6.5 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole             4
# 6.56 inches, 1080 x 2376 px, 90 Hz Display with Small Notch            4
# 2.8 inches, 240 x 320 px Display                                       4
# 6.5 inches, 1600 x 720 px, 90 Hz Display with Water Drop Notch         4
# 6.7 inches, 1290 x 2796 px, 120 Hz Display                             4
# 6.56 inches, 720 x 1600 px Display with Water Drop Notch               4
# 6.6 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch       4
# 6.2 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole             4
# 6.78 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            4
# 6.78 inches, 1220 x 2652 px, 120 Hz Display with Punch Hole            4
# 6.6 inches, 720 x 1612 px, 90 Hz Display with Punch Hole               4
# 6.73 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            4
# 6.6 inches, 1600 x 720 px, 90 Hz Display with Water Drop Notch         4
# 6.7 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole             4
# 6.55 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            4
# 6.6 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole              3
# 6.64 inches, 1080 x 2388 px, 90 Hz Display with Water Drop Notch       3
# 6.7 inches, 1290 x 2796 px, 120 Hz Display with Dynamic Island         3
# 8.2 inches, 1916 x 2160 px, 144 Hz Display with Punch Hole             3
# 6.74 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch       3
# 6.7 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch       3
# 6.6 inches, 1080 x 2340 px, 120 Hz Display with Water Drop Notch       3
# 6.6 inches, 1080 x 2412 px, 144 Hz Display with Punch Hole             3
# 6.74 inches, 720 x 1650 px, 90 Hz Display with Punch Hole              3
# 6.51 inches, 1600 x 720 px Display with Punch Hole                     3
# 6.59 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole             3
# 6.1 inches, 1170 x 2532 px, 120 Hz Display with Large Notch            3
# 6.7 inches, 1200 x 2664 px, 120 Hz Display with Punch Hole             3
# 6.18 inches, 1080 x 2246 px Display with Large Notch                   3
# 6.7 inches, 1290 x 2796 px Display with Dynamic Island                 3
# 5.4 inches, 1080 x 2340 px Display                                     3
# 6.5 inches, 1080 x 2400 px Display with Water Drop Notch               3
# 6.8 inches, 1440 x 3040 px Display with Punch Hole                     3
# 6.1 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole              3
# 6.8 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole             3
# 6.74 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            3
# 6.82 inches, 1440 x 3168 px, 120 Hz Display with Punch Hole            3
# 6.5 inches, 1080 x 2400 px Display with Punch Hole                     3
# 6.44 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      3
# 6.78 inches, 1264 x 2780 px, 120 Hz Display with Punch Hole            3
# 6.51 inches, 720 x 1600 px Display with Punch Hole                     3
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Small Notch            3
# 6.5 inches, 720 x 1600 px Display with Punch Hole                      3
# 6.6 inches, 720 x 1600 px Display with Water Drop Notch                3
# 6.1 inches, 1080 x 2520 px, 120 Hz Display                             3
# 5 inches, 854 x 480 px Display                                         3
# 6.1 inches, 1179 x 2556 px, 120 Hz Display                             3
# 6.49 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             3
# 6.2 inches, 720 x 1520 px Display with Water Drop Notch                3
# 6.8 inches, 1440 x 3088 px, 120 Hz Display with Punch Hole             3
# 6.56 inches, 720 x 1612 px, 90 Hz Display with Punch Hole              3
# 6.7 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole              3
# 6.3 inches, 1080 x 2340 px Display with Water Drop Notch               3
# 6.1 inches, 1179 x 2556 px Display with Dynamic Island                 3
# 6.82 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            3
# 6.9 inches, 1400 x 3200 px, 120 Hz Display with Punch Hole             3
# 6.78 inches, 1080 x 2400 px, 165 Hz Display                            3
# 6.58 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      3
# 6.7 inches, 2400 x 1080 px Display with Punch Hole                     3
# 6.38 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             3
# 6.1 inches, 828 x 1792 px Display with Large Notch                     3
# 6.1 inches, 1179 x 2556 px, 120 Hz Display with Dynamic Island         3
# 6.67 inches, 1080 x 2412 px, 120 Hz Display with Water Drop Notch      3
# 6.74 inches, 720 x 1600 px, 90 Hz Display with Punch Hole              3
# 6.73 inches, 1080 x 2408 px, 120 Hz Display with Punch Hole            3
# 6.8 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole              3
# 6.8 inches, 1080 x 2520 px, 120 Hz Display with Punch Hole             2
# 6.8 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole              2
# 6.78 inches, 1200 x 2652 px, 120 Hz Display with Punch Hole            2
# 6 inches, 1080 x 2520 px Display                                       2
# 6 inches, 720 x 1440 px Display                                        2
# 6.73 inches, 1290 x 2796 px, 120 Hz Display                            2
# 6.6 inches, 1612 x 720 px Display with Water Drop Notch                2
# 6.7 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch        2
# 6.55 inches, 1612 x 720 px, 90 Hz Display with Water Drop Notch        2
# 6.1 inches, 720 x 1560 px Display with Water Drop Notch                2
# 6.7 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole             2
# 6.1 inches, 750 x 1580 px Display                                      2
# 6.41 inches, 1080 x 2340 px Display with Water Drop Notch              2
# 6.1 inches, 828 x 1792 px Display                                      2
# 6.58 inches, 1080 x 2408 px, 90 Hz Display with Punch Hole             2
# 6.38 inches, 1080 x 2388 px, 90 Hz Display with Water Drop Notch       2
# 6.54 inches, 720 x 1560 px Display with Small Notch                    2
# 6.71 inches, 1080 x 2400 px Display with Punch Hole                    2
# 6.2 inches, 720 x 1680 px Display                                      2
# 6.7 inches, 720 x 1650 px Display with Punch Hole                      2
# 6.81 inches, 1080 x 2388 px Display                                    2
# 6.38 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch       2
# 6.9 inches, 1080 x 2640 px, 144 Hz Display with Punch Hole             2
# 6.71 inches, 1440 x 3214 px, 120 Hz Display with Punch Hole            2
# 6.2 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole             2
# 7.92 inches, 2088 x 2250 px Display                                    2
# 6.67 inches, 1080 x 2400 px, 165 Hz Display with Punch Hole            2
# 7.82 inches, 2268 x 2440 px, 120 Hz Display with Punch Hole            2
# 6.7 inches, 1080 x 2400 px, 165 Hz Display                             2
# 6.36 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            2
# 6.5 inches, 720 x 1600 px, 90 Hz Display                               2
# 8.02 inches, 1914 x 2160 px, 120 Hz Display with Punch Hole            2
# 6.28 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            2
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Dual Punch Hole        2
# 6.73 inches, 1080 x 2448 px, 165 Hz Display                            2
# 6.73 inches, 1440 x 3412 px, 144 Hz Display with Punch Hole            2
# 7.6 inches, 1768 x 2208 px, 120 Hz Display with Punch Hole             2
# 6.78 inches, 1080 x 2448 px, 144 Hz Display                            2
# 6.51 inches, 1080 x 2408 px, 144 Hz Display with Punch Hole            2
# 8.01 inches, 1860 x 2480 px, 90 Hz Display                             2
# 6.73 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            2
# 6.64 inches, 1080 x 2388 px, 90 Hz Display with Punch Hole             2
# 4.7 inches, 750 x 1334 px Display with Large Notch                     2
# 6.5 inches, 720 x 1560 px Display with Small Notch                     2
# 6.44 inches, 1080 x 2400 px Display with Small Notch                   2
# 6.82 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        2
# 6.71 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole            2
# 5.45 inches, 720 x 1440 px Display                                     2
# 6.43 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             2
# 6.78 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             2
# 6.8 inches, 1080 x 2400 px, 120 Hz Display                             2
# 5.9 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole             2
# 6.57 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            2
# 6.8 inches, 1080 x 2460 px Display                                     2
# 3.54 inches, 640 x 960 px Display                                      2
# 6.1 inches, 720 x 1560 px Display with Punch Hole                      2
# 6.26 inches, 720 x 1600 px Display with Large Notch                    2
# 6.4 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch         2
# 5.5 inches, 1080 x 1920 px Display                                     2
# 4.5 inches, 480 x 854 px Display                                       2
# 5.9 inches, 1080 x 2340 px Display with Water Drop Notch               2
# 6.5 inches, 1242 x 2688 px Display with Large Notch                    2
# 6.53 inches, 1176 x 2400 px Display with Large Notch                   2
# 6.9 inches, 1440 x 3200 px Display with Punch Hole                     2
# 7.4 inches, 1440 x 3200 px Display                                     2
# 6.8 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole              2
# 6.5 inches, 1080 x 2400 px, 120 Hz Display                             2
# 6.67 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            2
# 5.42 inches, 1080 x 2340 px Display with Punch Hole                    2
# 6.82 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole            2
# 6.91 inches, 1080 x 2460 px Display with Punch Hole                    2
# 6.78 inches, 1224 x 2700 px, 120 Hz Display with Punch Hole            2
# 6.78 inches, 1080 x 2400 px Display with Punch Hole                    2
# 6 inches, 1080 x 2160 px Display                                       2
# 6.4 inches, 1080 x 2340 px Display with Punch Hole                     2
# 6.7 inches, 1344 x 2992 px, 120 Hz Display with Punch Hole             2
# 6 inches, 720 x 1600 px Display                                        2
# 6.9 inches, 1080 x 2640 px, 165 Hz Display with Punch Hole             2
# 8.03 inches, 1916 x 2160 px, 120 Hz Display with Punch Hole            2
# 6.56 inches, 720 x 1600 px, 90 Hz Display with Punch Hole              2
# 5 inches, 720 x 1280 px Display                                        2
# 6.14 inches, 1080 x 2400 px Display with Punch Hole                    2
# 6.7 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole             2
# 6.6 inches, 1600 x 720 px Display with Punch Hole                      2
# 6.55 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            2
# 6.57 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            2
# 6.22 inches, 1520 x 720 px Display with Water Drop Notch               2
# 6.43 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            2
# 2.7 inches, 240 x 320 px Display                                       2
# 6.64 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            2
# 6.82 inches, 1116 x 2480 px, 144 Hz Display                            2
# 6.5 inches, 1600 x 720 px, 90 Hz Display with Punch Hole               2
# 6.7 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole              2
# 6.22 inches, 720 x 1520 px Display with Water Drop Notch               2
# 6.3 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole              2
# 6.39 inches, 1080 x 2340 px Display                                    2
# 6.67 inches, 1080 x 2408 px, 120 Hz Display with Punch Hole            2
# 6.82 inches, 720 x 1640 px, 90 Hz Display with Water Drop Notch        1
# 6.06 inches, 1170 x 2532 px, 120 Hz Display with Punch Hole            1
# 6.5 inches, 1440 x 3168 px Display with Water Drop Notch               1
# 6.82 inches, 720 x 1640 px, 90 Hz Display with Punch Hole              1
# 6.53 inches, 1080 x 2340 px Display with Punch Hole                    1
# 4.7 inches, 1080 x 1920 px Display                                     1
# 6.62 inches, 1080 x 2412 px, 144 Hz Display with Water Drop Notch      1
# 6.4 inches, 720 x 1560 px Display with Punch Hole                      1
# 6.52 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        1
# 6.82 inches, 1640 x 720 px, 90 Hz Display with Punch Hole              1
# 6.2 inches, 1440 x 2960 px Display                                     1
# 6.6 inches, 1260 x 2730 px, 240 Hz Display with Punch Hole             1
# 6.52 inches, 720 x 1600 px, 90 Hz Display with Punch Hole              1
# 6.73 inches, 1440 x 3120 px, 120 Hz Display with Punch Hole            1
# 6.66 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        1
# 6.67 inches, 1080 x 2160 px, 90 Hz Display with Punch Hole             1
# 6.28 inches, 1080 x 2280 px Display                                    1
# 6 inches, 1440 x 2880 px Display                                       1
# 6.74 inches, 1212 x 2616 px, 120 Hz Display                            1
# 6.4 inches, 720 x 1600 px Display with Water Drop Notch                1
# 6.78 inches, 1080 x 2460 px Display with Water Drop Notch              1
# 6.8 inches, 1080 x 2448 px, 165 Hz Display                             1
# 6.5 inches, 720 x 1600 px, 120 Hz Display with Punch Hole              1
# 6.53 inches, 720 x 1600 px, 90 Hz Display with Punch Hole              1
# 6.09 inches, 1520 x 720 px Display with Water Drop Notch               1
# 6.34 inches, 1080 x 2400 px Display with Punch Hole                    1
# 6.2 inches, 1520 x 720 px Display with Water Drop Notch                1
# 6.83 inches, 1200 x 2860 px, 144 Hz Display with Punch Hole            1
# 6.8 inches, 1200 x 2400 px, 120 Hz Display with Punch Hole             1
# 6 inches, 1080 x 2520 px, 90 Hz Display                                1
# 5.7 inches, 1080 x 2280 px Display                                     1
# 5.3 inches, 720 x 1480 px Display                                      1
# 6.4 inches, 1440 x 3040 px Display with Punch Hole                     1
# 6.5 inches, 1080 x 2400 px, 144 Hz Display                             1
# 6.67 inches, 1080 x 2340 px, 144 Hz Display with Punch Hole            1
# 6.51 inches, 1600 x 720 px, 90 Hz Display with Water Drop Notch        1
# 6.67 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole             1
# 6.5 inches, 720 x 1544 px Display with Water Drop Notch                1
# 6.83 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole            1
# 6.71 inches, 1284 x 2778 px, 120 Hz Display with Small Notch           1
# 6.67 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            1
# 6.81 inches, 1080 x 2400 px Display with Punch Hole                    1
# 5 inches, 1080 x 1920 px Display                                       1
# 6.58 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.7 inches, 1440 x 3200 px Display with Punch Hole                     1
# 4 inches, 480 x 640 px Display                                         1
# 6.78 inches, 1080 x 2480 px, 90 Hz Display with Punch Hole             1
# 6.8 inches, 720 x 1600 px Display with Punch Hole                      1
# 6 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole                1
# 5.86 inches, 720 x 1520 px Display with Large Notch                    1
# 6.8 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole             1
# 6.5 inches, 1080 x 2412 px, 144 Hz Display                             1
# 6.44 inches, 1080 x 2400 px Display with Dual Punch Hole               1
# 6.7 inches, 1080 x 2520 px, 90 Hz Display with Punch Hole              1
# 6 inches, 2220 x 1080 px Display                                       1
# 6.76 inches, 1344 x 2772 px, 120 Hz Display with Punch Hole            1
# 6.6 inches, 1288 x 2700 px, 120 Hz Display with Punch Hole             1
# 6.67 inches, 2400 x 1080 px, 144 Hz Display with Punch Hole            1
# 6.8 inches, 1080 x 2460 px Display with Water Drop Notch               1
# 6.5 inches, 1080 x 2340 px Display                                     1
# 6.56 inches, 1080 x 2400 px, 90 Hz Display with Water Drop Notch       1
# 6.3 inches, 1080 x 2400 px Display with Punch Hole                     1
# 6.4 inches, 1080 x 2408 px Display with Water Drop Notch               1
# 6.82 inches, 720 x 1600 px Display with Water Drop Notch               1
# 6.53 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.58 inches, 1080 x 2412 px, 120 Hz Display with Water Drop Notch      1
# 6.43 inches, 1080 x 2400 px Display with Dual Punch Hole               1
# 6.38 inches, 1080 x 2340 px Display with Water Drop Notch              1
# 6.1 inches, 1560 x 720 px Display with Water Drop Notch                1
# 6.95 inches, 1080 x 2460 px Display with Punch Hole                    1
# 6.1 inches, 720 x 1520 px Display with Water Drop Notch                1
# 8 inches, 2200 x 2480 px Display                                       1
# 6.95 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole            1
# 6.62 inches, 2400 x 1080 px, 120 Hz Display with Punch Hole            1
# 7.2 inches, 1440 x 1920 px Display                                     1
# 6.06 inches, 1170 x 2532 px Display with Punch Hole                    1
# 6.76 inches, 1440 x 3200 px, 120 Hz Display with Small Notch           1
# 6.2 inches, 1440 x 3200 px Display with Punch Hole                     1
# 7 inches, 1440 x 3080 px, 120 Hz Display with Punch Hole               1
# 6.62 inches, 2408 x 1080 px Display with Punch Hole                    1
# 6.52 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.3 inches, 1080 x 2280 px Display                                     1
# 6.6 inches, 1080 x 2400 px, 144 Hz Display                             1
# 6.43 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            1
# 7.8 inches, 2200 x 2480 px, 120 Hz Display with Punch Hole             1
# 6.7 inches, 1440 x 3040 px Display                                     1
# 6.82 inches, 720 x 1560 px Display with Punch Hole                     1
# 6.74 inches, 720 x 1600 px Display with Water Drop Notch               1
# 6.78 inches, 1080 x 2388 px, 90 Hz Display with Punch Hole             1
# 6.51 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            1
# 6.75 inches, 720 x 1600 px, 90 Hz Display with Water Drop Notch        1
# 5.84 inches, 1080 x 2280 px Display with Small Notch                   1
# 6.39 inches, 1080 x 2316 px Display                                    1
# 5.2 inches, 720 x 1280 px Display                                      1
# 6.58 inches, 1200 x 2640 px, 90 Hz Display with Dual Punch Hole        1
# 6.92 inches, 1080 x 2460 px, 144 Hz Display                            1
# 6.6 inches, 1080 x 2400 px, 90 Hz Display with Dual Punch Hole         1
# 6.7 inches, 1080 x 2460 px, 165 Hz Display with Punch Hole             1
# 6.6 inches, 1080 x 2460 px, 90 Hz Display with Water Drop Notch        1
# 5.5 inches, 720 x 1440 px Display                                      1
# 6.78 inches, 1080 x 2400 px, 120 Hz Display                            1
# 6.5 inches, 1644 x 3840 px Display                                     1
# 6.76 inches, 1344 x 2772 px, 90 Hz Display with Punch Hole             1
# 6.8 inches, 1080 x 2400 px, 165 Hz Display                             1
# 6.44 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.43 inches, 1080 x 2340 px, 90 Hz Display with Punch Hole             1
# 6.9 inches, 1080 x 2460 px, 120 Hz Display                             1
# 6.59 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             1
# 7.8 inches, 1440 x 1920 px Display                                     1
# 6.67 inches, 1440 x 3120 px, 144 Hz Display with Punch Hole            1
# 6.78 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1800 x 3200 px, 120 Hz Display with Dynamic Island         1
# 6.5 inches, 1080 x 2340 px Display with Water Drop Notch               1
# 5.7 inches, 720 x 1560 px Display with Water Drop Notch                1
# 6.67 inches, 1080 x 2400 px, 165 Hz Display                            1
# 6.82 inches, 1260 x 2800 px, 144 Hz Display with Punch Hole            1
# 6.7 inches, 1200 x 2664 px, 144 Hz Display with Punch Hole             1
# 6.58 inches, 1080 x 2408 px, 120 Hz Display                            1
# 6.8 inches, 720 x 1640 px, 90 Hz Display with Punch Hole               1
# 8 inches, 1812 x 2176 px, 144 Hz Display with Punch Hole               1
# 6.58 inches, 1200 x 2400 px, 120 Hz Display with Water Drop Notch      1
# 6.72 inches, 1080 x 2400 px, 165 Hz Display with Punch Hole            1
# 6.8 inches, 1440 x 3200 px, 165 Hz Display with Punch Hole             1
# 6.71 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            1
# 6.81 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            1
# 7.85 inches, 2000 x 2296 px, 120 Hz Display                            1
# 6.78 inches, 1240 x 2772 px, 120 Hz Display with Punch Hole            1
# 6.78 inches, 1440 x 3412 px, 165 Hz Display with Punch Hole            1
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      1
# 6.74 inches, 1224 x 2688 px, 144 Hz Display with Punch Hole            1
# 6.71 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            1
# 5.02 inches, 720 x 1600 px Display with Punch Hole                     1
# 6.68 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            1
# 6.78 inches, 720 x 1650 px Display with Water Drop Notch               1
# 6.8 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch       1
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      1
# 6.67 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             1
# 5.92 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            1
# 6.78 inches, 1080 x 2520 px, 120 Hz Display with Punch Hole            1
# 6.36 inches, 1200 x 2670 px, 120 Hz Display with Punch Hole            1
# 6.82 inches, 1440 x 3420 px, 165 Hz Display with Punch Hole            1
# 6.6 inches, 1644 x 3840 px, 120 Hz Display                             1
# 6.64 inches, 1080 x 2388 px Display with Water Drop Notch              1
# 6.8 inches, 1200 x 2860 px, 144 Hz Display with Punch Hole             1
# 6.55 inches, 1080 x 2400 px, 144 Hz Display                            1
# 6.78 inches, 1264 x 2780 px, 144 Hz Display with Punch Hole            1
# 6.78 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            1
# 6.7 inches, 1080 x 2408 px, 120 Hz Display with Punch Hole             1
# 6.79 inches, 1260 x 2800 px, 144 Hz Display with Punch Hole            1
# 6.5 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole             1
# 6.83 inches, 1800 x 3440 px, 144 Hz Display with Punch Hole            1
# 6.74 inches, 1080 x 2400 px, 165 Hz Display with Punch Hole            1
# 6.78 inches, 2400 x 1200 px, 120 Hz Display with Punch Hole            1
# 6.72 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole            1
# 6.83 inches, 1440 x 3168 px, 144 Hz Display with Punch Hole            1
# 6.12 inches, 1200 x 2666 px, 120 Hz Display with Dynamic Island        1
# 6.67 inches, 1440 x 3200 px, 144 Hz Display with Punch Hole            1
# 6.72 inches, 1440 x 3200 px, 144 Hz Display with Punch Hole            1
# 6.12 inches, 1200 x 2600 px, 120 Hz Display with Small Notch           1
# 6.78 inches, 1080 x 2436 px, 120 Hz Display with Punch Hole            1
# 6.5 inches, Full HD+ Display with Punch Hole                           1
# 6.67 inches, 1220 x 2700 px, 120 Hz Display with Punch Hole            1
# 6.72 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1200 x 2480 px, 144 Hz Display with Punch Hole             1
# 6.67 inches, 1080 x 2340 px, 120 Hz Display with Water Drop Notch      1
# 6.6 inches, 720 x 1612 px, 120 Hz Display with Water Drop Notch        1
# 6.9 inches, 1800 x 3200 px, 165 Hz Display                             1
# 6.79 inches, 1368 x 3192 px, 120 Hz Display with Punch Hole            1
# 6.72 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole            1
# 6.73 inches, 1080 x 2480 px, 120 Hz Display with Punch Hole            1
# 6.72 inches, 1080 x 2400 px Display with Water Drop Notch              1
# 6.56 inches, 1200 x 2400 px, 90 Hz Display with Water Drop Notch       1
# 6.82 inches, 1212 x 2616 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole             1
# 6 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole               1
# 6.1 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole             1
# 5 inches, 480 x 854 px Display                                         1
# 6.78 inches, 1080 x 2460 px Display with Punch Hole                    1
# 6.46 inches, 1224 x 2700 px, 90 Hz Display with Punch Hole             1
# 7.63 inches, 1812 x 2176 px, 120 Hz Display with Punch Hole            1
# 3.03 inches, 480 x 854 px Display                                      1
# 7.56 inches, 1792 x 1920 px, 120 Hz Display with Punch Hole            1
# 6.8 inches, 1240 x 2772 px, 165 Hz Display with Punch Hole             1
# 6.74 inches, 1284 x 2800 px Display with Small Notch                   1
# 6.78 inches, 1080 x 2400 px, 165 Hz Display with Punch Hole            1
# 6.41 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.26 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            1
# 6.67 inches, 1080 x 2408 px, 120 Hz Display                            1
# 6.1 inches, 1080 x 2520 px Display                                     1
# 7.6 inches, 1840 x 2208 px, 120 Hz Display with Punch Hole             1
# 6.64 inches, 1080 x 2388 px Display with Punch Hole                    1
# 6.72 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      1
# 7.92 inches, 2156 x 2344 px, 120 Hz Display with Punch Hole            1
# 6.67 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             1
# 6.55 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            1
# 6.52 inches, 720 x 1560 px Display with Punch Hole                     1
# 6.68 inches, 1284 x 2778 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Water Drop Notch       1
# 6.5 inches, 720 x 1600 px Display with Small Notch                     1
# 6.67 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole             1
# 6.6 inches, 1440 x 3200 px, 120 Hz Display with Punch Hole             1
# 6.95 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole             1
# 6.9 inches, 1080 x 2460 px, 120 Hz Display with Punch Hole             1
# 5.4 inches, 1080 x 2340 px Display with Large Notch                    1
# 6.9 inches, 1080 x 2460 px, 90 Hz Display with Punch Hole              1
# 6.62 inches, 720 x 1612 px, 90 Hz Display with Punch Hole              1
# 6.82 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole            1
# 6.82 inches, 1260 x 2720 px, 120 Hz Display with Punch Hole            1
# 6.7 inches, 1080 x 2412 px, 90 Hz Display with Punch Hole              1
# 6.72 inches, 1080 x 2340 px, 120 Hz Display with Punch Hole            1
# 6.78 inches, 1080 x 2460 px, 90 Hz Display with Water Drop Notch       1
# 6.6 inches, 1080 x 2408 px Display with Punch Hole                     1
# 6.62 inches, 1080 x 2400 px, 120 Hz Display with Water Drop Notch      1
# 6.74 inches, 1080 x 2520 px, 120 Hz Display with Punch Hole            1
# 5.5 inches, 750 x 1334 px Display with Large Notch                     1
# 6.6 inches, 720 x 1640 px, 90 Hz Display with Punch Hole               1
# 6.8 inches, 720 x 1600 px Display with Water Drop Notch                1
# 6.82 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            1
# 6.8 inches, 1220 x 2700 px, 144 Hz Display with Punch Hole             1
# 6.51 inches, 1080 x 2460 px, 144 Hz Display with Punch Hole            1
# 6.82 inches, 1440 x 3200 px, 165 Hz Display with Punch Hole            1
# 6.78 inches, 1440 x 3200 px, 165 Hz Display with Punch Hole            1
# 6.81 inches, 1240 x 2772 px, 120 Hz Display with Punch Hole            1
# 5 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole               1
# 6.28 inches, 1080 x 2408 px, 120 Hz Display with Punch Hole            1
# 8 inches, 1080 x 2460 px, 120 Hz Display                               1
# 6.53 inches, 1080 x 2400 px Display with Water Drop Notch              1
# 6.7 inches, 720 x 1640 px Display with Water Drop Notch                1
# 7.9 inches, 2000 x 2296 px, 120 Hz Display                             1
# 6.81 inches, 1080 x 2388 px, 144 Hz Display with Punch Hole            1
# 7.71 inches, 2016 x 2348 px, 120 Hz Display with Punch Hole            1
# 6.3 inches, 1200 x 2600 px, 144 Hz Display with Small Notch            1
# 6.8 inches, 1080 x 2400 px, 144 Hz Display with Punch Hole             1
# 8.2 inches, 1914 x 2160 px, 144 Hz Display                             1
# 6.8 inches, 1800 x 3440 px, 165 Hz Display with Punch Hole             1
# 6.81 inches, 1312 x 2848 px, 120 Hz Display with Punch Hole            1
# 6.44 inches, 1080 x 2412 px, 90 Hz Display with Water Drop Notch       1
# 6.68 inches, 1284 x 2778 px Display with Punch Hole                    1
# 6.8 inches, 1080 x 2400 px Display with Punch Hole                     1
# Name: count, dtype: int64

# %%
df1['camera'].value_counts()
# Out:
# camera
# 50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                       92
# 50 MP + 2 MP Dual Rear & 8 MP Front Camera                                 72
# 64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                       70
# 50 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                       46
# 13 MP + 2 MP Dual Rear & 5 MP Front Camera                                 38
# 108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                      32
# 12 MP + 12 MP Dual Rear & 12 MP Front Camera                               31
# 64 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                       30
# 50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                        29
# 13 MP + 2 MP Dual Rear & 8 MP Front Camera                                 28
# 8 MP Rear & 5 MP Front Camera                                              28
# 64 MP Quad Rear & 32 MP Front Camera                                       28
# 13 MP Rear & 5 MP Front Camera                                             27
# 50 MP + 2 MP Dual Rear & 5 MP Front Camera                                 25
# 50 MP Dual Rear & 8 MP Front Camera                                        22
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                       21
# 50 MP Quad Rear & 8 MP Front Camera                                        21
# 50 MP + 8 MP Dual Rear & 16 MP Front Camera                                21
# 108 MP Quad Rear & 32 MP Front Camera                                      20
# 50 MP + 2 MP Dual Rear & 16 MP Front Camera                                20
# 48 MP Quad Rear & 13 MP Front Camera                                       19
# 48 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                       17
# 48 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                     17
# 108 MP Quad Rear & 16 MP Front Camera                                      16
# 13 MP Dual Rear & 8 MP Front Camera                                        16
# 50 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                     16
# 64 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                       15
# 64 MP + 2 MP Dual Rear & 16 MP Front Camera                                14
# 50 MP + 2 MP Triple Rear & 8 MP Front Camera                               14
# 200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                      14
# 50 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                       14
# 48 MP Quad Rear & 16 MP Front Camera                                       14
# 108 MP + 2 MP Dual Rear & 16 MP Front Camera                               13
# 48 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                        13
# 64 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                       13
# 12 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                     12
# 108 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                      12
# 50 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                      11
# 108 MP Quad Rear & 40 MP Front Camera                                      11
# 50 MP + 2 MP + 2 MP Triple Rear & 13 MP Front Camera                       11
# 64 MP Quad Rear & 16 MP Front Camera                                       11
# 50 MP Quad Rear & 32 MP Front Camera                                       11
# 12 MP + 12 MP + 8 MP Triple Rear & 32 MP Front Camera                      11
# 13 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                        10
# 13 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                        10
# 8 MP Dual Rear & 5 MP Front Camera                                         10
# 50 MP Quad Rear & 16 MP Front Camera                                       10
# 64 MP Quad Rear & 20 MP Front Camera                                        9
# 108 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                       9
# 108 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                      9
# 64 MP + 2 MP Dual Rear & 8 MP Front Camera                                  9
# 48 MP + 12 MP Dual Rear & 12 MP Front Camera                                9
# 50 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                       9
# 108 MP + 2 MP Dual Rear & 8 MP Front Camera                                 9
# 50 MP + Depth Sensor Dual Rear & 8 MP Front Camera                          8
# 50 MP + 2 MP Triple Rear & 16 MP Front Camera                               8
# 50 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                         8
# 50 MP + Depth Sensor Dual Rear & 5 MP Front Camera                          8
# 50 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         8
# 50 MP + 50 MP Dual Rear & 16 MP Front Camera                                8
# 50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front Camera                        8
# 64 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera                      8
# 64 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                        8
# 48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front Camera                        8
# 200 MP + 50 MP + 12 MP Triple Rear & 60 MP Front Camera                     7
# 48 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                        7
# 48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                       7
# 8 MP + Depth Sensor Dual Rear & 5 MP Front Camera                           7
# 50 MP + 12 MP + 5 MP Triple Rear & 32 MP Front Camera                       7
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera          7
# 64 MP + 8 MP + 2 MP Triple Rear & 50 MP Front Camera                        7
# 50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front Camera                       7
# 50 MP Quad Rear & 13 MP Front Camera                                        6
# 64 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                       6
# 64 MP + 12 MP + 5 MP Triple Rear & 32 MP Front Camera                       6
# 12 MP Rear & 7 MP Front Camera                                              6
# 64 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                        6
# 13 MP Dual Rear & 5 MP Front Camera                                         6
# 50 MP + 48 MP + 8 MP Triple Rear & 32 MP Front Camera                       6
# 5 MP Rear & 2 MP Front Camera                                               6
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP Front Camera                        6
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                                 6
# 50 MP + 12 MP + 10 MP Triple Rear & 12 MP Front Camera                      6
# 64 MP Quad Rear & 13 MP Front Camera                                        6
# 50 MP + 13 MP Dual Rear & 32 MP Front Camera                                6
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP Front Camera                      6
# 48 MP Quad Rear & 8 MP Front Camera                                         6
# 50 MP + 5 MP + 2 MP Triple Rear & 13 MP Front Camera                        6
# 8 MP + 0.08 MP Dual Rear & 5 MP Front Camera                                6
# 50 MP + 48 MP + 32 MP Triple Rear & 16 MP Front Camera                      6
# 200 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                       6
# 13 MP + 2 MP + 2 MP Triple Rear & 16 MP Front Camera                        6
# 100 MP + 2 MP Dual Rear & 16 MP Front Camera                                6
# 2 MP Rear Camera                                                            5
# 64 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                         5
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                                5
# 50 MP Dual Rear & 5 MP Front Camera                                         5
# 108 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                       5
# 50 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                      5
# 48 MP + 2 MP Dual Rear & 8 MP Front Camera                                  5
# 50 MP + 2 MP + 2 MP Triple Rear & 5 MP Front Camera                         5
# 50 MP + 0.08 MP Dual Rear & 8 MP Front Camera                               5
# 200 MP Quad Rear & 32 MP Front Camera                                       5
# 50 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                       5
# 13 MP Rear & 8 MP Front Camera                                              5
# 48 MP + 2 MP Dual Rear & 5 MP Front Camera                                  4
# 64 MP + 12 MP + 5 MP Triple Rear & 10 MP Front Camera                       4
# 108 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera           4
# 64 MP + 13 MP Dual Rear & 32 MP Front Camera                                4
# 64 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                      4
# 200 MP Quad Rear & 12 MP Front Camera                                       4
# 48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                        4
# 200 MP + 13 MP + 2 MP Triple Rear & 32 MP Front Camera                      4
# 50 MP + 50 MP + 13 MP Triple Rear & 32 MP Front Camera                      4
# 50 MP + 8 MP + 2 MP Triple Rear & 44 MP Front Camera                        4
# 50 MP + 13 MP + 8 MP Triple Rear & 16 MP Front Camera                       4
# 48 MP + 13 MP + 13 MP Triple Rear & 16 MP Front Camera                      4
# 50 MP + 50 MP + 12 MP Triple Rear & 60 MP Front Camera                      4
# 16 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                        4
# 108 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                       4
# 50 MP + 0.3 MP Dual Rear & 5 MP Front Camera                                4
# 50 MP + 12 MP + 12 MP Triple Rear & 12 MP Front Camera                      4
# 8 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front Camera                        4
# 48 MP Quad Rear & 20 MP Front Camera                                        3
# 108 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                      3
# 64 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                        3
# 12 MP + 12 MP + 12 MP Triple Rear & 8 MP Front Camera                       3
# 13 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         3
# 200 MP Penta Rear & 32 MP Front Camera                                      3
# 64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera                       3
# 50 MP + 12 MP Dual Rear & 16 MP Front Camera                                3
# 64 MP Quad Rear & 10 MP Front Camera                                        3
# 50 MP Dual Rear & 32 MP Front Camera                                        3
# 12 MP + 8 MP + 8 MP Triple Rear & 8 MP Front Camera                         3
# 12 MP + 5 MP Dual Rear & 20 MP Front Camera                                 3
# 64 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera            3
# 50 MP + 5 MP + 2 MP Triple Rear & 16 MP Front Camera                        3
# 16 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                         3
# 8 MP + 0.3 MP Dual Rear & 5 MP Front Camera                                 3
# 64 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                       3
# 12 MP Quad Rear & 10 MP Front Camera                                        3
# 16 MP + 5 MP Dual Rear & 25 MP Front Camera                                 3
# 48 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                         3
# 16 MP + 2 MP Dual Rear & 8 MP Front Camera                                  3
# 50 MP + 32 MP + 8 MP Triple Rear & 32 MP Front Camera                       3
# 50 MP + 50 MP Dual Rear & 32 MP Front Camera                                3
# 108 MP + 2 MP Triple Rear & 16 MP Front Camera                              3
# 200 MP Quad Rear & 60 MP Front Camera                                       3
# 50 MP + 0.3 MP Dual Rear & 8 MP Front Camera                                3
# 64 MP Dual Rear & 16 MP Front Camera                                        3
# 12.2 MP + 12 MP Dual Rear & 8 MP Front Camera                               3
# 50 MP + 2 MP + 0.08 MP Triple Rear & 8 MP Front Camera                      3
# 64 MP + 50 MP + 50 MP Triple Rear & 16 MP Front Camera                      3
# 108 MP + 13 MP Dual Rear & 32 MP Front Camera                               3
# 50 MP + 50 MP + 50 MP Triple Rear & 50 MP Front Camera                      3
# 50 MP + 12 MP + 10 MP Triple Rear & 32 MP Front Camera                      3
# 50 MP + 0.08 MP Dual Rear & 16 MP Front Camera                              3
# 48 MP + 8 MP + 5 MP Triple Rear & 13 MP Front Camera                        3
# 50.3 MP Quad Rear & 32 MP Front Camera                                      3
# 64 MP + 2 MP Dual Rear & 32 MP Front Camera                                 2
# 50 MP + 2 MP + 0.3 MP Triple Rear & 8 MP Front Camera                       2
# 200 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera                     2
# 108 MP + 8 MP + 5 MP Triple Rear & 20 MP Front Camera                       2
# 50 MP + 13 MP + 12 MP Triple Rear & 16 MP Front Camera                      2
# 108 MP + 16 MP + 8 MP Triple Rear & 25 MP Front Camera                      2
# 64 MP + 13 MP + 2 MP Triple Rear & 16 MP Front Camera                       2
# 48 MP + 2 MP + Depth Sensor Triple Rear & 8 MP Front Camera                 2
# 12.2 MP Rear & 8 MP Front Camera                                            2
# 50 MP + 50 MP + 32 MP Triple Rear & 32 MP Front Camera                      2
# 64 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         2
# 50 MP + 12 MP Dual Rear & 12 MP Front Camera                                2
# 108 MP + 20 MP + 12 MP Triple Rear Camera                                   2
# 64 MP + 8 MP Dual Rear & 50 MP Front Camera                                 2
# 50 MP + 32 MP + 13 MP Triple Rear & 32 MP Front Camera                      2
# 64 MP + 48 MP + 48 MP Triple Rear & 32 MP + 20 MP Dual Front Camera         2
# 50 MP + 8 MP Dual Rear & 50 MP Front Camera                                 2
# 48 MP Quad Rear & 32 MP Front Camera                                        2
# 200 MP + 12 MP + 2 MP Triple Rear & 50 MP Front Camera                      2
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         2
# 20 MP + 16 MP Dual Rear & 16 MP Front Camera                                2
# 108 MP + 13 MP + 2 MP Triple Rear & 50 MP Front Camera                      2
# 40 MP Quad Rear & 32 MP Dual Front Camera                                   2
# 64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Front Camera                     2
# 64 MP + 16 MP + 12 MP Triple Rear & 16 MP Front Camera                      2
# 50 MP + 12 MP + 8 MP Triple Rear & 50 MP Front Camera                       2
# 108 MP + 0.08 MP Dual Rear & 32 MP Front Camera                             2
# 50 MP + 50 MP + 16 MP Triple Rear & 16 MP Front Camera                      2
# 50 MP + 12 MP + 8 MP Triple Rear & 10 MP Front Camera                       2
# 50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                       2
# 64 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera                       2
# 64 MP + 50 MP Triple Rear & 16 MP Front Camera                              2
# 64 MP Quad Rear & 16 MP + 8 MP Dual Front Camera                            2
# 108 MP + 13 MP + 2 MP Triple Rear & 60 MP Front Camera                      2
# 48 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                        2
# 108 MP + 50 MP + 32 MP Triple Rear & 32 MP Front Camera                     2
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP Front Camera                      2
# 48 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                        2
# 50 MP + 0.08 MP Dual Rear & 32 MP Front Camera                              2
# 50 MP + 12 MP Dual Rear & 8 MP Front Camera                                 2
# 12 MP Dual Rear & 5 MP Front Camera                                         2
# 16 MP + 12.2 MP Dual Rear & 8 MP Front Camera                               2
# 48 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                        2
# 108 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                       2
# 108 MP + 2 MP Dual Rear & 32 MP Front Camera                                2
# 50 MP + 50 MP + 12 MP Triple Rear & 20 MP Front Camera                      2
# 64 MP + 64 MP + 64 MP Triple Rear & 16 MP Front Camera                      2
# 48 MP + 2 MP Triple Rear & 32 MP Front Camera                               2
# 50 MP + 13 MP + 5 MP Triple Rear & 32 MP Front Camera                       2
# 48 MP + 2 MP Dual Rear & 16 MP Front Camera                                 2
# 8 MP Rear & 2 MP Front Camera                                               2
# 8 MP + 2 MP Dual Rear & 5 MP Front Camera                                   2
# 108 MP + 50 MP + 48 MP Triple Rear & 32 MP Front Camera                     2
# 50 MP + 12 MP Dual Rear & 10.5 MP Front Camera                              2
# 50 MP + 48 MP + 12 MP Triple Rear & 11.1 MP Front Camera                    2
# 200 MP + 50 MP + 50 MP Triple Rear & 60 MP Front Camera                     2
# 12 MP Rear & 10.8 MP Front Camera                                           2
# 54 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                       2
# 100 MP + 5 MP + 2 MP Triple Rear & 16 MP Front Camera                       2
# 200 MP + 50 MP + 48 MP Triple Rear & 32 MP Front Camera                     2
# 50 MP + 0.08 MP Dual Rear & 5 MP Front Camera                               2
# 64 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                            2
# 8 MP + 0.3 MP Dual Rear & 8 MP Front Camera                                 2
# 5 MP Rear Camera                                                            2
# 50 MP + 12 MP Dual Rear & 10.8 MP Front Camera                              2
# 64 MP + 2 MP Triple Rear & 32 MP Front Camera                               2
# 50 MP + 48 MP + 12 MP Triple Rear & 10.8 MP Front Camera                    2
# 108 MP + 5 MP + 2 MP Triple Rear & 16 MP Front Camera                       2
# 50 MP + 48 MP + 48 MP Triple Rear & 10.5 MP Front Camera                    2
# 108 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                      2
# 12 MP + 5 MP Dual Rear & 7 MP Front Camera                                  2
# 64 MP + 5 MP + 2 MP Triple Rear & 16 MP Front Camera                        2
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera          2
# 50 MP + 12 MP + 12 MP Triple Rear & 16 MP + 16 MP Dual Front Camera         2
# 20 MP Rear & 13 MP Front Camera                                             2
# 13 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                        2
# 50 MP + 50 MP + 2 MP Triple Rear & 16 MP Front Camera                       2
# 50 MP + 2 MP Dual Rear & 13 MP Front Camera                                 2
# 50 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                        2
# 64 MP + 13 MP + 5 MP Triple Rear & 24 MP Front Camera                       2
# 50 MP + 32 MP + 32 MP Triple Rear & 32 MP Front Camera                      2
# 64 MP + 12 MP + 2 MP Triple Rear & 16 MP Front Camera                       2
# 64 MP + 8 MP + 5 MP Triple Rear & 16 MP Front Camera                        2
# 48 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                       2
# 50 MP + 50 MP + 50 MP Triple Rear & 12 MP Front Camera                      1
# 2 MP Rear & 0.3 MP Front Camera                                             1
# 48 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 13 MP + 2 MP Triple Rear & 32 MP + 16 MP Dual Front Camera          1
# 13 MP Rear & 7 MP Front Camera                                              1
# 64 MP + 20 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 12 MP Quad Rear & 12 MP Front Camera                                        1
# 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera                        1
# 13 MP + Depth Sensor + Ultra Wide Triple Rear & 8 MP Front Camera           1
# 50 MP + 48 MP + 48 MP Triple Rear & 32 MP Front Camera                      1
# 48 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                        1
# 48 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 48 MP + 8 MP + 5 MP Triple Rear & 8 MP Front Camera                         1
# 108 MP + 64 MP + 16 MP Triple Rear & 32 MP Front Camera                     1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 13 MP Rear & 2.1 MP Front Camera                                            1
# 24 MP + 10 MP + 5 MP Triple Rear & 24 MP Front Camera                       1
# 64 MP + 13 MP Dual Rear & 16 MP Front Camera                                1
# 64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 50 MP + 13 MP + 8 MP Triple Rear & 48 MP + 8 MP Dual Front Camera           1
# 50 MP + 48 MP + 13 MP Triple Rear & 13 MP Front Camera                      1
# 16 MP + 13 MP + 13 MP Triple Rear & 8 MP Front Camera                       1
# 48 MP Triple Rear & 8 MP Front Camera                                       1
# 50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera                           1
# 108 MP + 8 MP + 8 MP Triple Rear & 16 MP Front Camera                       1
# 24 MP + 8 MP + 5 MP Triple Rear & 24 MP Front Camera                        1
# 12 MP Quad Rear & 8 MP Front Camera                                         1
# 16 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera                      1
# 48 MP Quad Rear Camera                                                      1
# 13 MP Rear & 16 MP Front Camera                                             1
# 50 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 200 MP + 50 MP + 8 MP Triple Rear & 50 MP Front Camera                      1
# 50 MP + 8 MP Dual Rear & 10.1 MP Front Camera                               1
# 50 MP + 50 MP + 50 MP Triple Rear & 20 MP Front Camera                      1
# 50 MP Quad Rear & 32 MP Dual Front Camera                                   1
# 13 MP + 2 MP Dual Rear & 20 MP Front Camera                                 1
# 12 MP + 12 MP Dual Rear & 8 MP Front Camera                                 1
# 13 MP + 2 MP Triple Rear & 8 MP Front Camera                                1
# 13 MP Rear & 13 MP Front Camera                                             1
# 47.2 MP + 1.9 MP Dual Rear & 12.6 MP Front Camera                           1
# 50 MP Quad Rear & 48 MP + 8 MP Dual Front Camera                            1
# 48 MP + 12.2 MP + 12.2 MP Triple Rear & 16 MP Front Camera                  1
# 48 MP + 12 MP + 5 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 8 MP + 2 MP Triple Rear & 60 MP Front Camera                        1
# 50 MP + 13 MP Dual Rear & 16 MP Front Camera                                1
# 50 MP + 3 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 50 MP + 2 MP Triple Rear & 5 MP Front Camera                                1
# 16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual Front Camera                 1
# 64 MP + 16 MP Dual Rear & 20 MP Front Camera                                1
# 12 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 108 MP + 20 MP + 16 MP Triple Rear & 32 MP Front Camera                     1
# 12 MP + 2 MP Dual Rear & 8 MP Front Camera                                  1
# 13 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 48 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                            1
# 108 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                      1
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP + 8 MP Dual Front Camera            1
# 50 MP + 20 MP + 12 MP Triple Rear & 13 MP Dual Front Camera                 1
# 64 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP Quad Rear & 13 MP Dual Front Camera                                   1
# 64 MP + 2 MP Triple Rear & 16 MP Front Camera                               1
# 64 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                       1
# 12 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 50 MP + 16 MP + 13 MP Triple Rear & 32 MP Front Camera                      1
# 16 MP Rear & 13 MP Front Camera                                             1
# 13 MP Quad Rear & 8 MP Front Camera                                         1
# 48 MP Quad Rear & 16 MP + 2 MP Dual Front Camera                            1
# 13 MP + 2 MP Dual Rear & 16 MP Front Camera                                 1
# 13 MP + 2 MP Dual Rear & 13 MP Front Camera                                 1
# 108 MP Quad Rear & 20 MP Front Camera                                       1
# 48 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                        1
# 64 MP + 50 MP + 13 MP Triple Rear & 13 MP Front Camera                      1
# 50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera                     1
# 50 MP + 13 MP Dual Rear & 13 MP Front Camera                                1
# 200 MP Quad Rear & 16 MP Front Camera                                       1
# 5 MP + 0.3 MP Dual Rear & 5 MP Front Camera                                 1
# 50 MP + 50 MP Triple Rear & 16 MP Front Camera                              1
# 5 MP Rear & 5 MP Front Camera                                               1
# 16 MP + 12 MP + 12 MP Triple Rear & 10 MP + 8 MP Dual Front Camera          1
# 50 MP + 12 MP Dual Rear & 32 MP Front Camera                                1
# 64 MP Quad Rear & 44 MP + 8 MP Dual Front Camera                            1
# 108 MP + 100 MP + 2 MP Triple Rear & 32 MP Front Camera                     1
# 50 MP + 32 MP + 12 MP Triple Rear & 50 MP + 2 MP Dual Front Camera          1
# 64 MP + 8 MP Dual Rear & 32 MP Front Camera                                 1
# 48 MP + 48 MP + 12 MP Triple Rear & 12 MP Front Camera                      1
# 50 MP + 50 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 108 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# 50 MP + 50 MP + 32 MP Triple Rear & 12 MP + 12 MP Dual Front Camera         1
# 50 MP + 50 MP + 13 MP Triple Rear & 32 MP + 16 MP Dual Front Camera         1
# 108 MP + 8 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 160 MP + 50 MP + 50 MP Triple Rear & 12 MP Front Camera                     1
# 64 MP + 50 MP + Macro Triple Rear & 16 MP Front Camera                      1
# 108 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                      1
# 108 MP + 8 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 200 MP + 32 MP + 8 MP Triple Rear & 32 MP Front Camera                      1
# 13 MP + 12 MP Dual Rear & 32 MP Front Camera                                1
# 64 MP + 64 MP + 50 MP Triple Rear & 16 MP Front Camera                      1
# 50 MP + 48 MP + 12 MP Triple Rear & 13 MP Dual Front Camera                 1
# 50 MP + 50 MP + 32 MP Triple Rear & 12 MP Front Camera                      1
# 108 MP + 2 MP Dual Rear Camera                                              1
# 50 MP + 50 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# 48 MP + 48 MP + 40 MP Triple Rear & 13 MP Front Camera                      1
# 108 MP + 2 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 64 MP + 50 MP + 32 MP Triple Rear & 32 MP Front Camera                      1
# 200 MP + 32 MP + 12 MP Triple Rear & 50 MP + 2 MP Dual Front Camera         1
# 50 MP + 50 MP + 12 MP Triple Rear & 16 MP Front Camera                      1
# 200 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                      1
# 50 MP + 50 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 64 MP + 12 MP + 8 MP Triple Rear & 50 MP Front Camera                       1
# 64 MP + 32 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 64 MP + 50 MP + 48 MP Triple Rear & 32 MP Front Camera                      1
# 108 MP + 2 MP + 0.08 MP Triple Rear & 32 MP Front Camera                    1
# 200 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                     1
# 12 MP Dual Rear & 8 MP Front Camera                                         1
# 64 MP + 50 MP + 50 MP Triple Rear & 16 MP + 12 MP Dual Front Camera         1
# 13 MP + 0.08 MP Dual Rear & 8 MP Front Camera                               1
# 64 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 200 MP + 13 MP + 5 MP Triple Rear & 32 MP Front Camera                      1
# 12.2 MP + 12 MP Dual Rear & 10.1 MP Front Camera                            1
# 64 MP + 50 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 64 MP + 13 MP Dual Rear & 13 MP Front Camera                                1
# 48 MP + 48 MP + 13 MP Triple Rear & 13 MP Front Camera                      1
# 50 MP + 2 MP + 0.08 MP Triple Rear & 32 MP Front Camera                     1
# 50 MP + 13 MP + 5 MP Triple Rear & 16 MP Front Camera                       1
# 200 MP + 32 MP + 5 MP Triple Rear & 32 MP Front Camera                      1
# 50 MP + 50 MP + 12 MP Triple Rear & 50 MP Front Camera                      1
# 50 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera                       1
# 16 MP Dual Rear & 8 MP Front Camera                                         1
# 200 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                       1
# 50 MP + 12 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 8 MP Dual Rear & 12 MP Front Camera                                 1
# 108 MP + 64 MP + 64 MP Triple Rear & 16 MP Front Camera                     1
# 48 MP + 8 MP + 8 MP Triple Rear & 8 MP Front Camera                         1
# 48 MP + 10.8 MP + 10.8 MP Triple Rear & 9.5 MP + 8 MP Dual Front Camera     1
# 50 MP + 50 MP + 20 MP Triple Rear & 16 MP Front Camera                      1
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP + 8 MP Dual Front Camera            1
# 13 MP + 0.3 MP Dual Rear & 5 MP Front Camera                                1
# 50 MP + 50 MP + 3 MP Triple Rear & 32 MP Front Camera                       1
# 108 MP + 8 MP + 2 MP Triple Rear & 12 MP Front Camera                       1
# 64 MP + 13 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 108 MP + 50 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera        1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 50.3 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                    1
# 50 MP + 50 MP + 2 MP Triple Rear & 60 MP Front Camera                       1
# 13 MP + Depth Sensor Dual Rear & 5 MP Front Camera                          1
# 50 MP + 50 MP + 13 MP Triple Rear & 16 MP Front Camera                      1
# 50 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera            1
# 50.3 MP + 50 MP + 12 MP Triple Rear & 32 MP Front Camera                    1
# 54 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                        1
# 200 MP + 13 MP + 2 MP Triple Rear & 60 MP Front Camera                      1
# 200 MP + 12 MP + 12 MP Triple Rear & 32 MP + 32 MP Dual Front Camera        1
# 50 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                        1
# 50 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 21 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 100 MP + 48 MP + 13 MP Triple Rear & 32 MP Front Camera                     1
# 100 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                       1
# 48 MP + 5 MP Dual Rear & 16 MP Front Camera                                 1
# 108 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                        1
# 50 MP + 50 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         1
# 50 MP + 12 MP Dual Rear & 50 MP Front Camera                                1
# 108 MP + 32 MP + 2 MP Triple Rear & 32 MP Front Camera                      1
# 200 MP + 48 MP + 13 MP Triple Rear & 50 MP Front Camera                     1
# 50 MP + 16 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# 48 MP Rear & 8 MP Front Camera                                              1
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera           1
# 50 MP Quad Rear & 12 MP Dual Front Camera                                   1
# 50 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 50 MP + 48 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 108 MP + 5 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 64 MP + 50 MP + 50 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         1
# 108 MP + 20 MP + 5 MP Triple Rear & 32 MP Front Camera                      1
# 200 MP + 24 MP + 16 MP Triple Rear & 32 MP Front Camera                     1
# 50 MP + 50 MP + Depth Sensor Triple Rear & 50 MP Front Camera               1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                      1
# Name: count, dtype: int64

# %%
temp=df1[df1['camera'].str.contains('Display', case=False, na=False)]

# %%
df1.loc[temp.index,'camera']=temp['extra_storage'].values

# %%
df['extra_storage'].value_counts()
# Out:
# extra_storage
# Memory Card Supported, upto 1 TB                                           385
# Memory Card Not Supported                                                  227
# Memory Card (Hybrid), upto 1 TB                                            214
# Android v13                                                                179
# Android v12                                                                169
# Memory Card Supported, upto 512 GB                                         149
# Memory Card Supported                                                      147
# Memory Card Supported, upto 256 GB                                         107
# Memory Card (Hybrid)                                                        66
# Android v11                                                                 55
# Android v14                                                                 53
# Memory Card Supported, upto 2 TB                                            35
# Memory Card Supported, upto 32 GB                                           19
# Memory Card (Hybrid), upto 256 GB                                           18
# Memory Card Supported, upto 128 GB                                          17
# Bluetooth                                                                   16
# Android v10                                                                 14
# Memory Card (Hybrid), upto 512 GB                                           13
# iOS v14                                                                      8
# 50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 MP Dual Front Camera           7
# Memory Card Supported, upto 64 GB                                            6
# Android v15                                                                  6
# Memory Card (Hybrid), upto 128 GB                                            5
# 0.3 MP Rear Camera                                                           5
# 12 MP + 12 MP Dual Rear & 10 MP Front Camera                                 5
# 50 MP Quad Rear & 16 MP Front Camera                                         4
# 50 MP + 8 MP Dual Rear & 32 MP Front Camera                                  3
# 1.3 MP Rear Camera                                                           3
# Memory Card (Hybrid), upto 64 GB                                             3
# Android v9.0 (Pie)                                                           3
# Flyme 10                                                                     3
# Dual Display                                                                 3
# 64 MP + 16 MP + 12 MP Triple Rear & 16 MP Front Camera                       2
# 64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Front Camera                      2
# 50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                        2
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          2
# iOS v15                                                                      2
# 64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front Camera                        2
# iOS v14.0                                                                    2
# 108 MP + 13 MP + 8 MP Triple Rear & 20 MP Front Camera                       2
# Nucleus                                                                      2
# 12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 MP Dual Front Camera           2
# Android v10.0                                                                2
# Memory Card Supported, upto 1000 GB                                          2
# Memory Card (Hybrid), upto 2 TB                                              2
# Memory Card Supported, upto 16 GB                                            2
# 64 MP + 48 MP + 48 MP Triple Rear & 32 MP + 20 MP Dual Front Camera          2
# 50 MP + 12 MP + 12 MP Triple Rear & 16 MP + 16 MP Dual Front Camera          2
# iOS v16                                                                      2
# 64 MP + 13 MP Dual Rear & 32 MP Front Camera                                 2
# 5 MP Rear Camera                                                             2
# 2 MP Rear Camera                                                             2
# Android v12.1                                                                2
# iOS v13                                                                      2
# 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera                         1
# iOS v10                                                                      1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                       1
# 50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera                            1
# 48 MP Quad Rear Camera                                                       1
# 50 MP + 16 MP + 13 MP Triple Rear & 32 MP Front Camera                       1
# Browser                                                                      1
# 5 MP Rear & 2 MP Front Camera                                                1
# Memory Card Supported, upto 48 GB                                            1
# HarmonyOS v2.0                                                               1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera                        1
# 50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front Camera                        1
# HarmonyOS                                                                    1
# 50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera                      1
# v1.7                                                                         1
# 50 MP + 50 MP + 20 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 12 MP Dual Rear & 8 MP Front Camera                                  1
# Symbian v9.1                                                                 1
# 64 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                        1
# KaiOS v2.5.3                                                                 1
# 50 MP + 50 MP + 32 MP Triple Rear & 12 MP + 12 MP Dual Front Camera          1
# 50 MP + 50 MP + 13 MP Triple Rear & 32 MP + 16 MP Dual Front Camera          1
# 13 MP + 12 MP Dual Rear & 32 MP Front Camera                                 1
# 50 MP + 12 MP Dual Rear & 32 MP Front Camera                                 1
# 50 MP + 50 MP Dual Rear & 16 MP Front Camera                                 1
# 50 MP + 50 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# v30                                                                          1
# 48 MP + 10.8 MP + 10.8 MP Triple Rear & 9.5 MP + 8 MP Dual Front Camera      1
# 200 MP + 48 MP + 13 MP Triple Rear & 50 MP Front Camera                      1
# 50 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                       1
# 50 MP + 48 MP + 32 MP Triple Rear & 32 MP Front Camera                       1
# No FM Radio                                                                  1
# 64 MP + 50 MP + 50 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 108 MP + 20 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# Nucleus OS                                                                   1
# 200 MP + 12 MP + 12 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         1
# 108 MP + 50 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                       1
# Name: count, dtype: int64

# %%
temp=df1[df1['extra_storage'].str.contains('MP', case=False, na=False)]
temp
# Out:
# Empty DataFrame
# Columns: [mobile_name, price, rating, connectivity, processor, storage, battery, display, camera, extra_storage, os]
# Index: []

# %% [markdown]
# **here in temp we have those phones which do not support memory card thats why camera get shifted into extra_storage column during web scraping so we will replace these values by "memory card not supported**

# %%
df1.loc[temp.index,'extra_storage']='Memory Card Not Supported'

# %%
df1['extra_storage'].value_counts()
# Out:
# extra_storage
# Memory Card Supported, upto 1 TB       385
# Memory Card Not Supported              311
# Memory Card (Hybrid), upto 1 TB        214
# Android v13                            179
# Android v12                            169
# Memory Card Supported, upto 512 GB     149
# Memory Card Supported                  146
# Memory Card Supported, upto 256 GB     107
# Memory Card (Hybrid)                    66
# Android v11                             55
# Android v14                             53
# Memory Card Supported, upto 2 TB        35
# Memory Card (Hybrid), upto 256 GB       18
# Android v10                             14
# Memory Card (Hybrid), upto 512 GB       13
# Memory Card Supported, upto 128 GB      10
# Memory Card Supported, upto 32 GB        6
# Android v15                              6
# Memory Card (Hybrid), upto 128 GB        5
# Android v9.0 (Pie)                       3
# Flyme 10                                 3
# Memory Card (Hybrid), upto 64 GB         3
# iOS v13                                  2
# Memory Card (Hybrid), upto 2 TB          2
# Memory Card Supported, upto 1000 GB      2
# Android v10.0                            2
# Android v12.1                            2
# iOS v10                                  1
# HarmonyOS v2.0                           1
# HarmonyOS                                1
# Name: count, dtype: int64

# %%
temp=df1[~df1['extra_storage'].str.contains('Memory',case=False,na=False)]
temp
# Out:
# Empty DataFrame
# Columns: [mobile_name, price, rating, connectivity, processor, storage, battery, display, camera, extra_storage, os]
# Index: []

# %%
df1.loc[temp.index,'os']=temp['extra_storage'].values

# %%
df1.loc[temp.index,'extra_storage']='Memory Card Not Supported'

# %%
df1['extra_storage'].value_counts()
# Out:
# extra_storage
# Memory Card Not Supported              802
# Memory Card Supported, upto 1 TB       385
# Memory Card (Hybrid), upto 1 TB        214
# Memory Card Supported, upto 512 GB     149
# Memory Card Supported                  146
# Memory Card Supported, upto 256 GB     107
# Memory Card (Hybrid)                    66
# Memory Card Supported, upto 2 TB        35
# Memory Card (Hybrid), upto 256 GB       18
# Memory Card (Hybrid), upto 512 GB       13
# Memory Card Supported, upto 128 GB      10
# Memory Card Supported, upto 32 GB        6
# Memory Card (Hybrid), upto 128 GB        5
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card (Hybrid), upto 2 TB          2
# Memory Card Supported, upto 1000 GB      2
# Name: count, dtype: int64

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                           623
# Android v13                           514
# Android v11                           375
# Android v14                           116
# Android v10                            82
# Android v9.0 (Pie)                     38
# Android v10.0                          29
# Memory Card Not Supported              23
# iOS v16                                20
# iOS v15                                18
# iOS v17                                14
# Android v8.1 (Oreo)                    12
# Android v15                            10
# iOS v14                                 8
# iOS v13                                 7
# Android v11.0                           5
# iOS v18                                 4
# Android v8.0 (Oreo)                     4
# Android v12.1                           4
# iOS v15.0                               3
# Memory Card (Hybrid), upto 2 TB         3
# Hongmeng OS v4.0                        3
# Flyme 10                                3
# iOS v13.0                               3
# Memory Card Supported, upto 32 GB       2
# Android v5.1.1 (Lollipop)               2
# EMUI v12                                2
# Android v6.0 (Marshmallow)              2
# HarmonyOS v2.0                          2
# Memory Card (Hybrid), upto 256 GB       2
# Harmony v2.0                            2
# iOS v14.0                               2
# Memory Card Supported                   2
# iOS v12.3                               2
# Bluetooth                               2
# HarmonyOS v2                            2
# Android v5.1 (Lollipop)                 2
# Memory Card Supported, upto 256 GB      2
# Android v4.4.2 (KitKat)                 1
# HarmonyOS v4                            1
# Android                                 1
# Android v7.1 (Nougat)                   1
# HarmonyOS                               1
# Memory Card Supported, upto 128 GB      1
# iOS v20                                 1
# iOS v19                                 1
# Memory Card (Hybrid)                    1
# iOS v10                                 1
# Pragati OS (Powered by Android)         1
# HarmonyOS v3.1                          1
# Hongmeng OS v3.0                        1
# Android v9 (Pie)                        1
# Name: count, dtype: int64

# %%
temp=df1[df1['os'].str.contains('Memory',case=False,na=False)]
temp
# Out:
#                      mobile_name   price  rating  \
# 191                 OnePlus Open  136995    4.10
# 297    Asus ROG Phone 8 Ultimate  109900    4.75
# 339             Motorola Razr 40   44999    4.15
# 346              Nokia 2780 Flip    4990    4.25
# 450      Samsung Galaxy Z Flip 3   45429    4.20
# 485            Nokia 2720 V Flip    6199    4.25
# 502      Samsung Galaxy Z Flip 5   99999    4.00
# 532       Motorola Razr 40 Ultra   72999    4.20
# 539               OnePlus V Flip   79990    4.40
# 593                 Oppo Find N3  114990    4.55
# 603                  Vivo X Flip   71990    4.10
# 747                Honor V Purse   67990    4.40
# 762       Motorola Razr 50 Ultra   89990    4.70
# 763         Tecno Phantom V Flip   49999    4.55
# 769            OPPO Find N3 Flip   94999    4.65
# 805              Oppo Find N2 5G   94990    4.30
# 828   Samsung Galaxy Z Flip 4 5G   64999    4.25
# 852                 LG V60 ThinQ   79990    4.05
# 901                 OPPO Find N4  119900    4.15
# 954               Honor Magic V2  102999    4.50
# 1174             Nokia 2780 Flip    4990     NaN
# 1178             Oppo Find N2 5G   94990     NaN
# 1290           Nokia 2720 V Flip    6199     NaN
# 1325     Samsung Galaxy Z Flip 3   69999   84.00
# 1341            Royole FlexPai 2  109999   87.00
# 1384            OPPO Find N Flip   89990   88.00
# 1411           OPPO Find N2 Flip   70990   88.00
# 1523  Samsung Galaxy Z Flip 4 5G   89999   88.00
# 1589                  LG Wing 5G   54999   89.00
# 1632                Oukitel WP21   22990   82.00
# 1701                LG V60 ThinQ   79990     NaN
# 1740  Asus ROG Phone 6D Ultimate  107990     NaN
# 1745            Huawei Mate Xs 2  162990   89.00
# 1863                CAT S22 Flip   14999     NaN
# 1913         Royole FlexPai 3 5G  149999   87.00
# 2012               Huawei Mate X  169000     NaN
#
#                                            connectivity  \
# 191   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 297             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 339             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 346                             Dual Sim, 3G, 4G, Wi-Fi
# 450             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 485                      Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 502     Single Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC
# 532             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 539           Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 593   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 603             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 747   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 762             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 763             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 769             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 805             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 828             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 852             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 901             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 954   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 1174                            Dual Sim, 3G, 4G, Wi-Fi
# 1178            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1290                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1325          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1341                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 1384          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1411          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1523            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1589            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1632                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 1701            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1740            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1745    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 1863                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 1913                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2012  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                               processor  \
# 191     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 297     Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor
# 339     Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor
# 346      Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 450       Snapdragon 888, Octa Core, 2.84 GHz Processor
# 485       Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 502    Snapdragon 8 Gen 2, Octa Core, 3.2 GHz Processor
# 532   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 539   Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 593     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 603    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 747       Snapdragon 778G, Octa Core, 2.4 GHz Processor
# 762    Snapdragon  8 Gen2, Octa Core, 3.2 GHz Processor
# 763          Dimensity 8050, Octa Core, 3 GHz Processor
# 769       Dimensity 9200, Octa Core, 3.05 GHz Processor
# 805    Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 828   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 852      Snapdragon  865, Octa Core, 2.84 GHz Processor
# 901                                 Octa Core Processor
# 954     Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 1174     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 1178   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 1290      Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 1325      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 1341      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 1384      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 1411  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 1523  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 1589    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 1632            Helio G99, Octa Core, 2.2 GHz Processor
# 1701     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 1740  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 1745      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 1863         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 1913      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 2012          Kirin  990, Octa Core, 2.86 GHz Processor
#
#                         storage                                   battery  \
# 191   16 GB RAM, 512 GB inbuilt   4805 mAh Battery with 67W Fast Charging
# 297   16 GB RAM, 512 GB inbuilt   6000 mAh Battery with 65W Fast Charging
# 339    8 GB RAM, 256 GB inbuilt   4200 mAh Battery with 30W Fast Charging
# 346    4 GB RAM, 512 MB inbuilt                          1450 mAh Battery
# 450    8 GB RAM, 128 GB inbuilt   3300 mAh Battery with 15W Fast Charging
# 485    512 MB RAM, 4 GB inbuilt                          1500 mAh Battery
# 502    8 GB RAM, 256 GB inbuilt   3700 mAh Battery with 25W Fast Charging
# 532    8 GB RAM, 256 GB inbuilt   3800 mAh Battery with 30W Fast Charging
# 539   12 GB RAM, 256 GB inbuilt   4500 mAh Battery with 67W Fast Charging
# 593   12 GB RAM, 512 GB inbuilt   4805 mAh Battery with 67W Fast Charging
# 603   12 GB RAM, 256 GB inbuilt   4400 mAh Battery with 44W Fast Charging
# 747   16 GB RAM, 256 GB inbuilt   4500 mAh Battery with 35W Fast Charging
# 762   12 GB RAM, 256 GB inbuilt   4200 mAh Battery with 44W Fast Charging
# 763    8 GB RAM, 256 GB inbuilt   4000 mAh Battery with 45W Fast Charging
# 769   12 GB RAM, 256 GB inbuilt   4300 mAh Battery with 44W Fast Charging
# 805   12 GB RAM, 256 GB inbuilt   4520 mAh Battery with 67W Fast Charging
# 828    8 GB RAM, 128 GB inbuilt   3700 mAh Battery with 25W Fast Charging
# 852    8 GB RAM, 128 GB inbuilt       5000 mAh Battery with Fast Charging
# 901   12 GB RAM, 256 GB inbuilt  4820 mAh Battery with 120W Fast Charging
# 954   16 GB RAM, 256 GB inbuilt   5000 mAh Battery with 66W Fast Charging
# 1174   4 GB RAM, 512 MB inbuilt                          1450 mAh Battery
# 1178  12 GB RAM, 256 GB inbuilt   4520 mAh Battery with 67W Fast Charging
# 1290   512 MB RAM, 4 GB inbuilt                          1500 mAh Battery
# 1325   8 GB RAM, 128 GB inbuilt   3300 mAh Battery with 15W Fast Charging
# 1341   8 GB RAM, 128 GB inbuilt                          4450 mAh Battery
# 1384   8 GB RAM, 128 GB inbuilt   4300 mAh Battery with 44W Fast Charging
# 1411   8 GB RAM, 256 GB inbuilt   4300 mAh Battery with 44W Fast Charging
# 1523   8 GB RAM, 128 GB inbuilt   3700 mAh Battery with 25W Fast Charging
# 1589   8 GB RAM, 128 GB inbuilt       4000 mAh Battery with Fast Charging
# 1632  12 GB RAM, 256 GB inbuilt   9800 mAh Battery with 66W Fast Charging
# 1701   8 GB RAM, 128 GB inbuilt       5000 mAh Battery with Fast Charging
# 1740  16 GB RAM, 512 GB inbuilt   6000 mAh Battery with 65W Fast Charging
# 1745   8 GB RAM, 512 GB inbuilt   4600 mAh Battery with 66W Fast Charging
# 1863    2 GB RAM, 16 GB inbuilt                          2000 mAh Battery
# 1913   8 GB RAM, 128 GB inbuilt                          3360 mAh Battery
# 2012   8 GB RAM, 512 GB inbuilt   4500 mAh Battery with 55W Fast Charging
#
#                                                 display  \
# 191   7.82 inches, 2268 x 2440 px, 120 Hz Display wi...
# 297         6.78 inches, 1080 x 2448 px, 165 Hz Display
# 339   6.9 inches, 1080 x 2640 px, 144 Hz Display wit...
# 346                    2.7 inches, 240 x 320 px Display
# 450   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 485                    2.8 inches, 240 x 320 px Display
# 502   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 532   6.9 inches, 1080 x 2640 px, 165 Hz Display wit...
# 539   6.78 inches, 1080 x 2520 px, 120 Hz Display wi...
# 593   7.82 inches, 2268 x 2440 px, 120 Hz Display wi...
# 603   6.74 inches, 1080 x 2520 px, 120 Hz Display wi...
# 747   7.71 inches, 2016 x 2348 px, 120 Hz Display wi...
# 762   6.9 inches, 1080 x 2640 px, 165 Hz Display wit...
# 763   6.9 inches, 1080 x 2640 px, 144 Hz Display wit...
# 769   6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 805   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 828   6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 852   6.8 inches, 1080 x 2460 px Display with Punch ...
# 901   7.56 inches, 1792 x 1920 px, 120 Hz Display wi...
# 954   7.92 inches, 2156 x 2344 px, 120 Hz Display wi...
# 1174                   2.7 inches, 240 x 320 px Display
# 1178  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 1290                   2.8 inches, 240 x 320 px Display
# 1325  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 1341                 7.8 inches, 1440 x 1920 px Display
# 1384  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 1411  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 1523  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 1589                 6.8 inches, 1080 x 2460 px Display
# 1632        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 1701  6.8 inches, 1080 x 2460 px Display with Punch ...
# 1740        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 1745  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 1863                     4 inches, 480 x 640 px Display
# 1913                 7.2 inches, 1440 x 1920 px Display
# 2012                   8 inches, 2200 x 2480 px Display
#
#                                                  camera  \
# 191   64 MP + 48 MP + 48 MP Triple Rear & 32 MP + 20...
# 297   64 MP + 13 MP + 8 MP Triple Rear & 32 MP Front...
# 339        64 MP + 13 MP Dual Rear & 32 MP Front Camera
# 346                                    5 MP Rear Camera
# 450        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 485                                    2 MP Rear Camera
# 502        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 532        13 MP + 12 MP Dual Rear & 32 MP Front Camera
# 539         50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 593   64 MP + 48 MP + 48 MP Triple Rear & 32 MP + 20...
# 603        50 MP + 12 MP Dual Rear & 32 MP Front Camera
# 747         50 MP + 12 MP Dual Rear & 8 MP Front Camera
# 762   50 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 763        64 MP + 13 MP Dual Rear & 32 MP Front Camera
# 769   50 MP + 48 MP + 32 MP Triple Rear & 32 MP Fron...
# 805   50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 828        12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 852   64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 901   108 MP + 50 MP + 32 MP Triple Rear & 32 MP + 3...
# 954   50 MP + 50 MP + 20 MP Triple Rear & 16 MP Fron...
# 1174                                   5 MP Rear Camera
# 1178  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 1290                                   2 MP Rear Camera
# 1325       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 1341  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 1384        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 1411        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 1523       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 1589  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 1632  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 1701  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 1740  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 1745  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 1863                      5 MP Rear & 2 MP Front Camera
# 1913  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 2012                             48 MP Quad Rear Camera
#
#                   extra_storage                                  os
# 191   Memory Card Not Supported           Memory Card Not Supported
# 297   Memory Card Not Supported           Memory Card Not Supported
# 339   Memory Card Not Supported           Memory Card Not Supported
# 346   Memory Card Not Supported   Memory Card Supported, upto 32 GB
# 450   Memory Card Not Supported           Memory Card Not Supported
# 485   Memory Card Not Supported               Memory Card Supported
# 502   Memory Card Not Supported           Memory Card Not Supported
# 532   Memory Card Not Supported           Memory Card Not Supported
# 539   Memory Card Not Supported           Memory Card Not Supported
# 593   Memory Card Not Supported           Memory Card Not Supported
# 603   Memory Card Not Supported           Memory Card Not Supported
# 747   Memory Card Not Supported           Memory Card Not Supported
# 762   Memory Card Not Supported           Memory Card Not Supported
# 763   Memory Card Not Supported           Memory Card Not Supported
# 769   Memory Card Not Supported           Memory Card Not Supported
# 805   Memory Card Not Supported           Memory Card Not Supported
# 828   Memory Card Not Supported           Memory Card Not Supported
# 852   Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 901   Memory Card Not Supported           Memory Card Not Supported
# 954   Memory Card Not Supported           Memory Card Not Supported
# 1174  Memory Card Not Supported   Memory Card Supported, upto 32 GB
# 1178  Memory Card Not Supported           Memory Card Not Supported
# 1290  Memory Card Not Supported               Memory Card Supported
# 1325  Memory Card Not Supported           Memory Card Not Supported
# 1341  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 1384  Memory Card Not Supported           Memory Card Not Supported
# 1411  Memory Card Not Supported           Memory Card Not Supported
# 1523  Memory Card Not Supported           Memory Card Not Supported
# 1589  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 1632  Memory Card Not Supported                Memory Card (Hybrid)
# 1701  Memory Card Not Supported     Memory Card (Hybrid), upto 2 TB
# 1740  Memory Card Not Supported           Memory Card Not Supported
# 1745  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB
# 1863  Memory Card Not Supported  Memory Card Supported, upto 128 GB
# 1913  Memory Card Not Supported  Memory Card Supported, upto 256 GB
# 2012  Memory Card Not Supported   Memory Card (Hybrid), upto 256 GB

# %%
df1.loc[temp.index,'extra_storage']=temp['os'].values

# %%
df1.loc[temp.index,'os']=np.nan

# %%
temp=df1[df1['os'].str.contains('Bluetooth',case=False,na=False)]
# Out:
#         mobile_name  price  rating             connectivity  \
# 516   Nokia 8000 4G   6899    4.55  Dual Sim, 3G, 4G, Wi-Fi
# 1505  Nokia 8000 4G   6899     NaN  Dual Sim, 3G, 4G, Wi-Fi
#
#                                           processor                   storage  \
# 516   Snapdragon  210, Quad Core, 1.1 GHz Processor  512 MB RAM, 4 GB inbuilt
# 1505  Snapdragon  210, Quad Core, 1.1 GHz Processor  512 MB RAM, 4 GB inbuilt
#
#                battery                           display            camera  \
# 516   1500 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
# 1505  1500 mAh Battery  2.8 inches, 240 x 320 px Display  2 MP Rear Camera
#
#               extra_storage         os
# 516   Memory Card Supported  Bluetooth
# 1505  Memory Card Supported  Bluetooth

# %%
df1.loc[temp.index,'os']=np.nan

# %%
df1['os'].value_counts()
# Out:
# os
# Android v12                        623
# Android v13                        514
# Android v11                        375
# Android v14                        116
# Android v10                         82
# Android v9.0 (Pie)                  38
# Android v10.0                       29
# iOS v16                             20
# iOS v15                             18
# iOS v17                             14
# Android v8.1 (Oreo)                 12
# Android v15                         10
# iOS v14                              8
# iOS v13                              7
# Android v11.0                        5
# Android v12.1                        4
# iOS v18                              4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# Hongmeng OS v4.0                     3
# iOS v13.0                            3
# Flyme 10                             3
# Bluetooth                            2
# iOS v12.3                            2
# iOS v14.0                            2
# Android v5.1 (Lollipop)              2
# HarmonyOS v2                         2
# EMUI v12                             2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# HarmonyOS v2.0                       2
# Harmony v2.0                         2
# Android                              1
# Android v7.1 (Nougat)                1
# HarmonyOS                            1
# Android v4.4.2 (KitKat)              1
# iOS v10                              1
# Pragati OS (Powered by Android)      1
# Hongmeng OS v3.0                     1
# iOS v20                              1
# iOS v19                              1
# HarmonyOS v4                         1
# HarmonyOS v3.1                       1
# Android v9 (Pie)                     1
# Name: count, dtype: int64

# %%
df1.shape
# Out:
# (1963, 11)

# %%
#lets run value_counts on each column check is there any error
for i in df1.columns[3:]:
    print(df1[i].value_counts())
    print('############# column end #############')
    print()
# Out:
# connectivity
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                      561
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi                               492
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           339
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Blaster          151
# Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster               120
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          101
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster                    75
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                 37
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC, IR Blaster     19
# Dual Sim, 3G, 4G, Wi-Fi                                       14
# Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster               12
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC                     10
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi                       7
# Single Sim, 3G, 4G, VoLTE, Wi-Fi, NFC                          6
# Single Sim, 3G, 4G, VoLTE, Wi-Fi                               5
# Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, IR Blaster           4
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi                           3
# Dual Sim, 3G, 4G, Wi-Fi, NFC                                   2
# Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster               1
# Single Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC                1
# Dual Sim, 3G, 4G, 5G, Wi-Fi, NFC                               1
# Single Sim, 3G, 4G, Wi-Fi, NFC                                 1
# Dual Sim, 3G, Wi-Fi                                            1
# Name: count, dtype: int64
# ############# column end #############
#
# processor
# Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor                          65
# Snapdragon 695, Octa Core, 2.2 GHz Processor                             57
# Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor                         55
# Dimensity 700 5G, Octa Core, 2.2 GHz Processor                           46
# Snapdragon 680, Octa Core, 2.4 GHz Processor                             45
# Helio P35, Octa Core, 2.3 GHz Processor                                  41
# Helio G99, Octa Core, 2.2 GHz Processor                                  40
# Dimensity 6020, Octa Core, 2.2 GHz Processor                             30
# Snapdragon  8 Gen1, Octa Core, 3 GHz Processor                           30
# Helio G35, Octa Core, 2.3 GHz Processor                                  29
# Snapdragon 8 Gen3, Octa Core, 3.3 GHz Processor                          29
# Dimensity 1080, Octa Core, 2.6 GHz Processor                             28
# Snapdragon 870, Octa Core, 3.2 GHz Processor                             27
# Snapdragon 8 Gen1, Octa Core, 3 GHz Processor                            27
# Helio G85, Octa Core, 2 GHz Processor                                    26
# Snapdragon  695, Octa Core, 2.2 GHz Processor                            25
# Bionic A15, Hexa Core, 3.22 GHz Processor                                25
# Snapdragon 778G, Octa Core, 2.4 GHz Processor                            24
# Snapdragon  680, Octa Core, 2.4 GHz Processor                            24
# Octa Core Processor                                                      23
# Dimensity  810 5G, Octa Core, 2.4 GHz Processor                          23
# Helio  G85, Octa Core, 2 GHz Processor                                   22
# Snapdragon 888, Octa Core, 2.84 GHz Processor                            20
# Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor                        20
# Helio G88, Octa Core, 2 GHz Processor                                    19
# Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor                        17
# Dimensity 7050, Octa Core, 2.6 GHz Processor                             16
# Helio G96, Octa Core, 2.05 GHz Processor                                 16
# Helio G80, Octa Core, 2 GHz Processor                                    16
# Snapdragon  888 , Octa Core, 2.84 GHz Processor                          16
# Dimensity 810 5G, Octa Core, 2.4 GHz Processor                           16
# Dimensity 8200, Octa Core, 3.1 GHz Processor                             15
# Dimensity  920 5G, Octa Core, 2.5 GHz Processor                          15
# Dimensity 6080, Octa Core, 2.4 GHz Processor                             15
# Helio G37, Octa Core, 2.3 GHz Processor                                  13
# Dimensity 1300, Octa Core, 3 GHz Processor                               13
# Tiger T612, Octa Core, 1.82 GHz Processor                                13
# Helio A22, Quad Core, 2 GHz Processor                                    12
# Snapdragon 7 Gen1, Octa Core, 2.4 GHz Processor                          11
# Dimensity 8100 Max, Octa Core, 2.85 GHz Processor                        10
# Bionic A14, Hexa Core, 3.1 GHz Processor                                 10
# Dimensity  8100, Octa Core, 2.85 GHz Processor                           10
# Exynos 1280, Octa Core, 2.4 GHz Processor                                10
# A13 Bionic, Hexa Core, 2.65 GHz Processor                                10
# Snapdragon  870, Octa Core, 3.2 GHz Processor                            10
# Helio G25, Octa Core, 2 GHz Processor                                    10
# Dimensity 8050, Octa Core, 3 GHz Processor                                9
# Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor                         9
# Snapdragon 865, Octa Core, 2.84 GHz Processor                             9
# Unisoc T612, Octa Core, 1.8 GHz Processor                                 9
# Dimensity 7200, Octa Core, 2.8 GHz Processor                              9
# Snapdragon 4 Gen2, Octa Core, 2.2 GHz Processor                           9
# Dimensity 9300, Octa Core, 3.25 GHz Processor                             9
# Helio G95, Octa Core, 2.05 GHz Processor                                  9
# Snapdragon 7+ Gen2, Octa Core, 2.91 GHz Processor                         9
# Snapdragon 8 Gen 2, Octa Core, 3.36 GHz Processor                         9
# Helio  G96, Octa Core, 2.05 GHz Processor                                 8
# Exynos  2100, Octa Core, 2.9 GHz Processor                                8
# Dimensity 9000, Octa Core, 3.05 GHz Processor                             8
# Snapdragon  8 Gen2, Octa Core, 3.2 GHz Processor                          8
# Exynos 1330, Octa Core, 2.4 GHz Processor                                 8
# Snapdragon 695 , Octa Core, 2.2 GHz Processor                             8
# Dimensity 1200, Octa Core, 3 GHz Processor                                8
# Exynos  1280, Octa Core, 2.4 GHz Processor                                8
# Snapdragon 720G, Octa Core, 2.3 GHz Processor                             8
# Unisoc T606, Octa Core, 1.6 GHz Processor                                 8
# Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor                            8
# Exynos 850, Octa Core, 2 GHz Processor                                    8
# Snapdragon  695 , Octa Core, 2.2 GHz Processor                            7
# Snapdragon  732G, Octa Core, 2.3 GHz Processor                            7
# Dimensity 9200, Octa Core, 3.05 GHz Processor                             7
# Bionic  A16, Hexa Core Processor                                          7
# Bionic  A16, Hexa Core, 3.46 GHz Processor                                7
# Exynos 990, Octa Core, 2.73 GHz Processor                                 7
# Unisoc SC9863A, Octa Core, 1.6 GHz Processor                              7
# Snapdragon  480 , Octa Core, 2 GHz Processor                              7
# Snapdragon 778G Plus, Octa Core, 2.5 GHz Processor                        7
# Dimensity 900, Octa Core, 2 GHz Processor                                 6
# Snapdragon  778G, Octa Core, 2.4 GHz Processor                            6
# Bionic  A17 Pro, Hexa Core, 3.78 GHz Processor                            6
# Exynos, Octa Core Processor                                               6
# Exynos  850, Octa Core, 2 GHz Processor                                   6
# Helio G36, Octa Core, 2.2 GHz Processor                                   6
# Snapdragon 685, Octa Core, 2.8 GHz Processor                              6
# Helio P22, Octa Core, 2 GHz Processor                                     6
# Quad Core, 1.3 GHz Processor                                              6
# Snapdragon 8 Gen3, Octa Core Processor                                    6
# Snapdragon  7 Gen1, Octa Core, 2.36 GHz Processor                         5
# Dimensity 8100-Max, Octa Core, 2.85 GHz Processor                         5
# Dimensity 900, Octa Core, 2.4 GHz Processor                               5
# Helio G70, Octa Core, 2 GHz Processor                                     5
# Helio  G99, Octa Core, 2.2 GHz Processor                                  5
# Unisoc  SC9863A, Octa Core, 1.6 GHz Processor                             5
# Snapdragon  778G , Octa Core, 2.4 GHz Processor                           5
# Helio, Octa Core Processor                                                5
# Snapdragon  480+, Octa Core, 2.2 GHz Processor                            5
# Dimensity 720, Octa Core, 2 GHz Processor                                 5
# Dimensity 810, Octa Core, 2.4 GHz Processor                               5
# Snapdragon 6 Gen 1, Octa Core, 2.2 GHz Processor                          5
# Helio G96, Octa Core, 2 GHz Processor                                     5
# Dimensity 800U, Octa Core, 2.4 GHz Processor                              5
# Snapdragon  888+, Octa Core, 2.9 GHz Processor                            5
# Exynos 1380, Octa Core, 2.4 GHz Processor                                 5
# Octa Core, 2 GHz Processor                                                4
# Snapdragon  865 , Octa Core, 2.84 GHz Processor                           4
# Snapdragon 845, Octa Core, 2.8 GHz Processor                              4
# Dimensity  1300, Octa Core, 3 GHz Processor                               4
# Unisoc  T606, Octa Core, 1.6 GHz Processor                                4
# Snapdragon 888+, Octa Core, 2.9 GHz Processor                             4
# Snapdragon 480+, Octa Core, 2.2 GHz Processor                             4
# Quad Core, 1.6 GHz Processor                                              4
# Dimensity 920 5G, Octa Core, 2.5 GHz Processor                            4
# Exynos  990, Octa Core, 2.73 GHz Processor                                4
# Snapdragon 855+, Octa Core, 2.96 GHz Processor                            4
# Snapdragon 732G , Octa Core, 2.3 GHz Processor                            4
# Dimensity  930, Octa Core, 2.2 GHz Processor                              4
# Snapdragon 778G+, Octa Core, 2.5 GHz Processor                            4
# Dimensity 700, Octa Core, 2.2 GHz Processor                               4
# Helio  G25, Octa Core, 2 GHz Processor                                    4
# Dimensity  9000, Octa Core, 3.05 GHz Processor                            4
# Dimensity 9200 Plus, Octa Core, 3.35 GHz Processor                        4
# Tiger T606, Octa Core, 2 GHz Processor                                    4
# Snapdragon 6 Gen1, Octa Core, 2.2 GHz Processor                           4
# Snapdragon 7s Gen 2, Octa Core, 2.4 GHz Processor                         4
# Snapdragon 8 Gen4, Octa Core Processor                                    4
# Dimensity  8200, Octa Core, 3.1 GHz Processor                             4
# Snapdragon  720G, Octa Core, 2.3 GHz Processor                            3
# Snapdragon  439 , Octa Core, 2 GHz Processor                              3
# Dimensity 8020, Octa Core Processor                                       3
# Snapdragon 712, Octa Core, 2.3 GHz Processor                              3
# Snapdragon 7 Gen3, Octa Core, 2.63 GHz Processor                          3
# Tiger  T616, Octa Core, 2 GHz Processor                                   3
# Snapdragon  675, Octa Core, 2 GHz Processor                               3
# Snapdragon 678, Octa Core, 2.2 GHz Processor                              3
# Exynos 9611, Octa Core, 2.3 GHz Processor                                 3
# Snapdragon 782G, Octa Core, 2.7 GHz Processor                             3
# Dimensity 6100 Plus, Octa Core Processor                                  3
# Tiger T616, Octa Core, 2 GHz Processor                                    3
# Snapdragon  4 Gen 1, Octa Core, 2 GHz Processor                           3
# Kirin  990, Octa Core, 2.86 GHz Processor                                 3
# Helio  G88, Octa Core, 2 GHz Processor                                    3
# Helio G37, Octa Core, 1.8 GHz Processor                                   3
# Dimensity  700 5G, Octa Core, 2.2 GHz Processor                           3
# Snapdragon 765G, Octa Core, 2.4 GHz Processor                             3
# Snapdragon  665, Octa Core, 2 GHz Processor                               3
# Dimensity 7200 Ultra, Octa Core, 2.8 GHz Processor                        3
# Helio G95, Octa Core, 2 GHz Processor                                     3
# Snapdragon 765G , Octa Core, 2.4 GHz Processor                            3
# Qualcomm 215, Quad Core, 1.3 GHz Processor                                3
# Bionic  A16                                                               3
# Exynos 1280 , Octa Core, 2.4 GHz Processor                                3
# Tiger  T616, Octa Core, 1.8 GHz Processor                                 3
#  Snapdragon  695, Octa Core, 2.2 GHz Processor                            3
# Snapdragon  782G, Octa Core, 2.7 GHz Processor                            3
# Snapdragon 695 5G, Octa Core, 2.2 GHz Processor                           3
# Dimensity 700 , Octa Core, 2.2 GHz Processor                              3
# Dimensity 8020, Octa Core, 2.6 GHz Processor                              3
# Exynos 1330, Octa Core Processor                                          3
# Unisoc  T606, Octa Core, 2 GHz Processor                                  3
# Tiger  T310, Quad Core, 2 GHz Processor                                   3
# Helio G85 , Octa Core, 2 GHz Processor                                    3
# Snapdragon 860, Octa Core, 2.96 GHz Processor                             3
# Snapdragon 778G+, Octa Core Processor                                     3
# Snapdragon  750G, Octa Core, 2.2 GHz Processor                            3
# Dimensity  900, Octa Core, 2 GHz Processor                                3
# Exynos 9825, Octa Core, 2.73 GHz Processor                                3
# Google  Tensor G2, Octa Core, 2.85 GHz Processor                          3
# Google  Tensor, Octa Core Processor                                       3
# Dimensity 800U , Octa Core, 2.4 GHz Processor                             2
# Snapdragon 7 Gen1, Octa Core, 2.36 GHz Processor                          2
# Dimensity  900, Octa Core, 2.4 GHz Processor                              2
# Unisoc T606, Octa Core, 2 GHz Processor                                   2
# Snapdragon  8 Gen3, Octa Core, 3.3 GHz Processor                          2
# Dimensity  900 5G, Octa Core, 2.4 GHz Processor                           2
# Snapdragon  8 Gen3, Octa Core Processor                                   2
# Unisoc  SC9836A, Quad Core, 1.6 GHz Processor                             2
# Tiger T700, Octa Core, 1.8 GHz Processor                                  2
# Snapdragon  810, Octa Core, 2.4 GHz Processor                             2
# Quad Core, 1.4 GHz Processor                                              2
# Helio MT6580, Quad Core, 1.3 GHz Processor                                2
# Samsung Exynos 7885, Octa Core, 2.2 GHz Processor                         2
# Octa Core, 1.6 GHz Processor                                              2
# Snapdragon  865, Octa Core, 2.84 GHz Processor                            2
# Snapdragon  720G , Octa Core, 2.3 GHz Processor                           2
# Unisoc SC7731E, Quad Core, 1.3 GHz Processor                              2
# Snapdragon 7s Gen2, Octa Core Processor                                   2
# Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Processor                        2
# Tensor G3, Nine Core, 3 GHz Processor                                     2
# Spreadtrum  SC7731E, Quad Core, 1.3 GHz Processor                         2
# Snapdragon 205 , Dual Core, 1.1 GHz Processor                             2
# Snapdragon QM215, Quad Core, 1.3 GHz Processor                            2
# Bionic  A17, Octa Core Processor                                          2
# Snapdragon 460, Octa Core, 1.8 GHz Processor                              2
# Helio P60, Octa Core, 2 GHz Processor                                     2
# Snapdragon 439, Octa Core, 2 GHz Processor                                2
# Bionic A16                                                                2
# Snapdragon  750G , Octa Core, 2.2 GHz Processor                           2
# Helio P95, Octa Core, 2.2 GHz Processor                                   2
# Snapdragon  888, Octa Core, 2.84 GHz Processor                            2
# Unisoc  SC9863a, Octa Core, 1.6 GHz Processor                             2
# Dimensity 700, Octa Core, 2 GHz Processor                                 2
# Unisoc  T610, Octa Core, 1.8 GHz Processor                                2
# Snapdragon 690, Octa Core, 2 GHz Processor                                2
# Snapdragon  765G , Octa Core, 2.4 GHz Processor                           2
# Helio P35 , Octa Core, 2.3 GHz Processor                                  2
# Dimensity 8100, Octa Core, 2.85 GHz Processor                             2
# Snapdragon 865 , Octa Core, 2.84 GHz Processor                            2
# Bionic  A15, Hexa Core, 3.22 GHz Processor                                2
# Snapdragon  778G Plus, Octa Core, 2.5 GHz Processor                       2
# Dimensity 9200, Octa Core Processor                                       2
# Snapdragon 662 , Octa Core, 2 GHz Processor                               2
# Exynos 9820, Octa Core, 2.7 GHz Processor                                 2
# Dimensity 7030, Octa Core, 2.5 GHz Processor                              2
# Google Tensor G2, Octa Core, 2.85 GHz Processor                           2
# Dimensity 7020, Octa Core, 2.2 GHz Processor                              2
# SC9863A, Octa Core, 1.6 GHz Processor                                     2
# Google  Tensor, Octa Core, 2.8 GHz Processor                              2
# Unisoc T603, Octa Core Processor                                          2
# Dimensity 7020, Octa Core Processor                                       2
# Helio  P22 , Octa Core, 2 GHz Processor                                   2
# Snapdragon  690 , Octa Core, 2 GHz Processor                              2
# Dimensity  1200 Max, Octa Core, 3 GHz Processor                           2
# Snapdragon 7 Gen 1 Accelerated Edition, Octa Core, 2.36 GHz Processor     2
# Dimensity 7200, Octa Core Processor                                       2
# Snapdragon 720G , Octa Core, 2.3 GHz Processor                            2
# Helio G99 Ultra, Octa Core Processor                                      2
# Snapdragon  855, Octa Core, 2.8 GHz Processor                             2
# Snapdragon 732G, Octa Core, 2.3 GHz Processor                             2
# Snapdragon  6 Gen 1, Octa Core, 2.2 GHz Processor                         2
# Snapdragon 8 Gen 3, Octa Core, 3.3 GHz Processor                          2
# Tensor G3, Nine Cores, 3 GHz Processor                                    2
# Dimensity 8200 Ultra, Octa Core, 3.1 GHz Processor                        2
# Tiger T310, Quad Core, 2 GHz Processor                                    2
# Spreadtrum SC9863A1, Octa Core, 1.6 GHz Processor                         2
# Snapdragon  210, Quad Core, 1.1 GHz Processor                             2
# Dimensity 8300 Ultra, Octa Core, 3.35 GHz Processor                       2
# Dimensity 9200 Plus, Octa Core, 3.05 GHz Processor                        2
# Spreadtrum  SC9863A, Octa Core, 1.6 GHz Processor                         2
# Apple  A13                                                                2
# Dimensity 930, Octa Core, 2.2 GHz Processor                               2
# Exynos 2100, Octa Core, 2.9 GHz Processor                                 2
# Kirin 9000S, Octa Core, 2.62 GHz Processor                                2
# Bionic A17, Octa Core Processor                                           2
# Exynos 2200, Octa Core, 2.8 GHz Processor                                 2
# Exynos 7904, Octa Core, 1.8 GHz Processor                                 1
# Helio  P22, Octa Core, 2 GHz Processor                                    1
# Snapdragon  712 , Octa Core, 2.3 GHz Processor                            1
# Snapdragon  730G, Octa Core, 2.2 GHz Processor                            1
# Tiger  T610, Octa Core, 1.8 GHz Processor                                 1
# Snapdragon 8 Gen1 , Octa Core, 3 GHz Processor                            1
# Snapdragon  765G, Octa Core, 2.4 GHz Processor                            1
# Google Tensor 3, Octa Core Processor                                      1
# Octa Core, 2.2 GHz Processor                                              1
# Dimensity 6080, Octa Core Processor                                       1
# Dimensity 1100 5G, Octa Core, 2.6 GHz Processor                           1
# Helio A25, Octa Core, 1.8 GHz Processor                                   1
# Snapdragon 662, Octa Core, 2 GHz Processor                                1
# Spreadtrum  SC7731, Quad Core, 1.3 GHz Processor                          1
# Snapdragon 730G, Octa Core, 2.2 GHz Processor                             1
# Exynos 9810, Octa Core, 2.7 GHz Processor                                 1
# Kirin 9000E, Octa Core, 3.13 GHz Processor                                1
# Dimensity 8100 Ultra, Octa Core, 2.85 GHz Processor                       1
# Exynos 9825, Octa Core, 2.7 GHz Processor                                 1
# Tiger T610, Octa Core, 1.8 GHz Processor                                  1
# Dimensity 8300, Octa Core, 3.35 GHz Processor                             1
# Helio P60, Octa Core, 1.99 GHz Processor                                  1
# Snapdragon 8+ Gen 1 , Octa Core, 3.19 GHz Processor                       1
# Exynos  9611 , Octa Core, 2.3 GHz Processor                               1
# Snapdragon 8+ Gen2, Octa Core, 3.36 GHz Processor                         1
# Snapdragon  662 , Octa Core, 2 GHz Processor                              1
# Snapdragon 870 , Octa Core, 3.2 GHz Processor                             1
# Snapdragon 665, Octa Core, 2 GHz Processor                                1
# Helio P35, Octa Core, 1.8 GHz Processor                                   1
# Helio  G90T, Octa Core, 2.05 GHz Processor                                1
# Helio P70, Octa Core, 2.1 GHz Processor                                   1
# Helio P23, Octa Core, 2.5 GHz Processor                                   1
# Snapdragon MSM8939, Octa Core, 1.5 GHz Processor                          1
# Bionic A16, Hexa Core Processor                                           1
# Snapdragon 8 Gen 2, Octa Core, 3.2 GHz Processor                          1
# Kirin 990, Octa Core, 2.86 GHz Processor                                  1
# Unisoc  A55, Octa Core, 1.6 GHz Processor                                 1
# Snapdragon 450, Octa Core, 1.8 GHz Processor                              1
# Octa Core, 1.8 GHz Processor                                              1
# Snapdragon 710, Octa Core, 2.2 GHz Processor                              1
# Exynos 7885, Octa Core, 2.2 GHz Processor                                 1
# Snapdragon 425, Quad Core, 1.2 GHz Processor                              1
# Spreadtrum  SC9832E, Quad Core, 1.4 GHz Processor                         1
# Dimensity 1000+, Octa Core, 2.6 GHz Processor                             1
# Spreadtrum  SC9832E , Quad Core, 1.4 GHz Processor                        1
# Snapdragon  7 Gen1, Octa Core, 2.4 GHz Processor                          1
# Snapdragon  7 Gen2, Octa Core Processor                                   1
# Bionic  A19, Deca Core Processor                                          1
# Snapdragon 675, Octa Core, 2 GHz Processor                                1
# Snapdragon 439, Octa Core, 1.95 GHz Processor                             1
# Dimensity  9200, Octa Core Processor                                      1
# Exynos 9810, Octa Core, 2.8 GHz Processor                                 1
# Snapdragon  778G+, Octa Core Processor                                    1
# Snapdragon 680 , Octa Core, 2.4 GHz Processor                             1
# Helio   G90T , Octa Core, 2.05 GHz Processor                              1
# (28 nm), Quad Core, 1.5 GHz Processor                                     1
# Kirin  810, Octa Core, 2.2 GHz Processor                                  1
# Helio  P65 , Octa Core, 2 GHz Processor                                   1
# Helio P70, Octa Core, 2 GHz Processor                                     1
# Qualcomm Snapdragon 670, Octa Core, 2 GHz Processor                       1
# Kirin 659, Octa Core, 2.36 GHz Processor                                  1
# Qualcomm Snapdragon 625, Octa Core, 2 GHz Processor                       1
# Helio G99 Ultimate, Octa Core, 2.2 GHz Processor                          1
# Snapdragon 835, Octa Core, 2.35 GHz Processor                             1
# Tiger T610, Quad Core, 1.8 GHz Processor                                  1
# Tiger  T616 , Octa Core, 2 GHz Processor                                  1
# Exynos 1200, Octa Core, 2.4 GHz Processor                                 1
# Snapdragon 460 , Octa Core, 1.8 GHz Processor                             1
# Exynos 1280, Octa Core Processor                                          1
# Dimensity 8200 Ultra , Octa Core, 3.1 GHz Processor                       1
# Dimensity (6 nm), Octa Core, 2.6 GHz Processor                            1
# Snapdragon  7 Gen3, Octa Core, 2.63 GHz Processor                         1
# Google  Tensor G4, Octa Core Processor                                    1
# Snapdragon 750G, Octa Core, 2.2 GHz Processor                             1
# Bionic A18 Pro, Hexa Core Processor                                       1
# Exynos 2300, Octa Core Processor                                          1
# Snapdragon 8 Gen1 Plus, Octa Core Processor                               1
# Snapdragon 480, Octa Core, 2 GHz Processor                                1
# Exynos 1480, Octa Core Processor                                          1
# Google Tensor 4, Octa Core Processor                                      1
# Snapdragon QCM6490, Octa Core, 2.7 GHz Processor                          1
# Kirin  9000, Octa Core, 3.13 GHz Processor                                1
# Helio, Octa Core, 2.2 GHz Processor                                       1
# Unisoc  SC9863A1, Octa Core Processor                                     1
# Dimensity  6020, Octa Core, 2.2 GHz Processor                             1
# Dimensity  9300, Octa Core, 3.25 GHz Processor                            1
# Snapdragon 845, Octa Core, 2.7 GHz Processor                              1
# Dimensity  8050, Octa Core, 3 GHz Processor                               1
# Dimensity  7200, Octa Core Processor                                      1
# Snapdragon  712, Octa Core, 2.3 GHz Processor                             1
# Snapdragon 8+ Gen2, Octa Core Processor                                   1
# Snapdragon 855, Octa Core, 2.84 GHz Processor                             1
# Snapdragon (4 nm), Octa Core, 3.2 GHz Processor                           1
# Snapdragon 750G , Octa Core, 2.2 GHz Processor                            1
# Bionic A18, Octa Core Processor                                           1
# Snapdragon 4 Gen1, Octa Core, 2 GHz Processor                             1
# Snapdragon 7 Gen3 , Octa Core, 2.63 GHz Processor                         1
#  Snapdragon 695, Octa Core, 2.2 GHz Processor                             1
# Tensor G3, Nine-Cores, 3 GHz Processor                                    1
# Tiger T7150, Quad Core, 1.8 GHz Processor                                 1
# Unisoc T610, Octa Core, 1.8 GHz Processor                                 1
# Fusion APL1024, Quad Core, 2.37 GHz Processor                             1
# Snapdragon 8 gen2, Octa Core, 3.2 GHz Processor                           1
# Snapdragon 425, Quad Core, 1.4 GHz Processor                              1
# Snapdragon 888+ , Octa Core, 2.9 GHz Processor                            1
# Snapdragon  680 , Octa Core, 2.4 GHz Processor                            1
# Sanpdragon 680, Octa Core, 2.4 GHz Processor                              1
# Unisoc  SC9832E, Quad Core, 1.4 GHz Processor                             1
# Snapdragon 615, Octa Core, 1.5 GHz Processor                              1
# Helio  G95, Octa Core, 2.05 GHz Processor                                 1
# Tensor G2, Octa Core, 2.85 GHz Processor                                  1
# Tiger T610, Octa Core, 1.82 GHz Processor                                 1
# Helio  P35, Octa Core, 2.3 GHz Processor                                  1
# Snapdragon 801, Octa Core, 1.5 GHz Processor                              1
# Snapdragon 775                                                            1
# Snapdragon  439, Octa Core, 2 GHz Processor                               1
# Snapdragon  8 Gen4, Octa Core Processor                                   1
# Snapdragon  7+ Gen2, Octa Core, 2.91 GHz Processor                        1
# Unisoc, Octa Core Processor                                               1
# Snapdragon 730, Octa Core, 2.2 GHz Processor                              1
# Bionic  A18 Pro, Hexa Core Processor                                      1
# Snapdragon 855, Octa Core, 2.8 GHz Processor                              1
# Snapdragon 8+ Gen 2, Octa Core Processor                                  1
# Dimensity 8300 Ultra, Octa Core Processor                                 1
# Helio  G37, Octa Core, 2.3 GHz Processor                                  1
# Google Tensor, Octa Core, 2.8 GHz Processor                               1
# Unisoc T820, Octa Core, 2.7 GHz Processor                                 1
# Exynos  2300, Octa Core Processor                                         1
# Exynos 1380, Octa Core Processor                                          1
# Google  Tensor 3, Octa Core Processor                                     1
# Name: count, dtype: int64
# ############# column end #############
#
# storage
# 8 GB RAM, 128 GB inbuilt     525
# 6 GB RAM, 128 GB inbuilt     330
# 12 GB RAM, 256 GB inbuilt    236
# 4 GB RAM, 64 GB inbuilt      232
# 8 GB RAM, 256 GB inbuilt     204
# 4 GB RAM, 128 GB inbuilt     124
# 3 GB RAM, 32 GB inbuilt       46
# 6 GB RAM, 64 GB inbuilt       41
# 12 GB RAM, 512 GB inbuilt     33
# 2 GB RAM, 32 GB inbuilt       30
# 16 GB RAM, 256 GB inbuilt     26
# 3 GB RAM, 64 GB inbuilt       22
# 6 GB RAM, 256 GB inbuilt      12
# 12 GB RAM, 128 GB inbuilt     10
# 1 GB RAM, 16 GB inbuilt       10
# 16 GB RAM, 512 GB inbuilt     10
# 2 GB RAM, 64 GB inbuilt        9
# 4 GB RAM, 32 GB inbuilt        9
# 6 GB RAM, 512 GB inbuilt       6
# 2 GB RAM, 16 GB inbuilt        5
# 6 GB RAM, 1 TB inbuilt         5
# 8 GB RAM, 512 GB inbuilt       5
# 4 GB RAM, 256 GB inbuilt       5
# 18 GB RAM, 512 GB inbuilt      4
# 512 MB RAM, 4 GB inbuilt       4
# 64 GB inbuilt                  3
# 12 GB RAM, 1 TB inbuilt        3
# 4 GB RAM, 512 MB inbuilt       2
# 8 GB RAM, 1 TB inbuilt         2
# 24 GB RAM, 1 TB inbuilt        2
# 4 GB RAM, 512 GB inbuilt       2
# 3 GB RAM, 16 GB inbuilt        2
# 256 GB inbuilt                 1
# 18 GB RAM, 256 GB inbuilt      1
# 512 GB inbuilt                 1
# 1 GB RAM, 8 GB inbuilt         1
# Name: count, dtype: int64
# ############# column end #############
#
# battery
# 5000 mAh Battery with 33W Fast Charging      204
# 5000 mAh Battery with 18W Fast Charging      174
# 5000 mAh Battery                             103
# 5000 mAh Battery with 67W Fast Charging       81
# 5000 mAh Battery with 10W Fast Charging       64
# 5000 mAh Battery with 25W Fast Charging       59
# 5000 mAh Battery with 80W Fast Charging       57
# 5000 mAh Battery with 120W Fast Charging      49
# 5000 mAh Battery with 15W Fast Charging       46
# 5000 mAh Battery with 44W Fast Charging       32
# 6000 mAh Battery with 18W Fast Charging       28
# 5000 mAh Battery with Fast Charging           27
# 5000 mAh Battery with 30W Fast Charging       27
# 5000 mAh Battery with 100W Fast Charging      26
# 5000 mAh Battery with 45W Fast Charging       24
# 4500 mAh Battery with 67W Fast Charging       22
# 4500 mAh Battery with 25W Fast Charging       22
# 4500 mAh Battery with 65W Fast Charging       21
# 4500 mAh Battery with 33W Fast Charging       21
# 6000 mAh Battery with 25W Fast Charging       21
# 4500 mAh Battery with 80W Fast Charging       20
# 4600 mAh Battery with 66W Fast Charging       19
# 4000 mAh Battery                              17
# 6000 mAh Battery with 15W Fast Charging       16
# 5000 mAh Battery with 65W Fast Charging       14
# 4700 mAh Battery with 80W Fast Charging       14
# 6000 mAh Battery with 65W Fast Charging       13
# 4500 mAh Battery with 44W Fast Charging       12
# 5000 mAh Battery with 68W Fast Charging       11
# 5000 mAh Battery with 20W Fast Charging       11
# 5000 mAh Battery with 150W Fast Charging      10
# 5000 mAh Battery with 66W Fast Charging        9
# 4500 mAh Battery with Fast Charging            9
# 4700 mAh Battery with 66W Fast Charging        9
# 4600 mAh Battery with 80W Fast Charging        8
# 4230 mAh Battery                               8
# 4300 mAh Battery with 30W Fast Charging        8
# 6000 mAh Battery with 33W Fast Charging        8
# 4400 mAh Battery with 25W Fast Charging        8
# 4000 mAh Battery with 33W Fast Charging        8
# 5080 mAh Battery with 67W Fast Charging        8
# 4800 mAh Battery with 150W Fast Charging       7
# 4300 mAh Battery with 44W Fast Charging        7
# 4500 mAh Battery with 45W Fast Charging        7
# 4700 mAh Battery with 120W Fast Charging       7
# 6000 mAh Battery with 44W Fast Charging        6
# 4800 mAh Battery with 67W Fast Charging        6
# 5500 mAh Battery with 67W Fast Charging        6
# 3000 mAh Battery                               6
# 4000 mAh Battery with Fast Charging            6
# 4800 mAh Battery with 66W Fast Charging        6
# 6000 mAh Battery                               6
# 5020 mAh Battery with 33W Fast Charging        6
# 4400 mAh Battery with 66W Fast Charging        6
# 3700 mAh Battery with 25W Fast Charging        6
# 4700 mAh Battery with 45W Fast Charging        6
# 3240 mAh Battery with Fast Charging            6
# 3279 mAh Battery with Fast Charging            5
# 4000 mAh Battery with 25W Fast Charging        5
# 5020 mAh Battery with 18W Fast Charging        5
# 4700 mAh Battery with 67W Fast Charging        5
# 4500 mAh Battery with 120W Fast Charging       5
# 6000 mAh Battery with 80W Fast Charging        5
# 4520 mAh Battery with 33W Fast Charging        5
# 4980 mAh Battery with 120W Fast Charging       5
# 4050 mAh Battery with 44W Fast Charging        5
# 4020 mAh Battery with 33W Fast Charging        5
# 4325 mAh Battery with Fast Charging            5
# 7000 mAh Battery with 33W Fast Charging        5
# 4250 mAh Battery with 33W Fast Charging        5
# 4323 mAh Battery with Fast Charging            4
# 4200 mAh Battery with 44W Fast Charging        4
# 5000 mAh Battery with 22.5W Fast Charging      4
# 4500 mAh Battery with 35W Fast Charging        4
# 3500 mAh Battery                               4
# 4600 mAh Battery with 240W Fast Charging       4
# 5160 mAh Battery with 67W Fast Charging        4
# 4600 mAh Battery with 120W Fast Charging       4
# 1500 mAh Battery                               4
# 5400 mAh Battery with 100W Fast Charging       4
# 4830 mAh Battery with 66W Fast Charging        4
# 4500 mAh Battery with 60W Fast Charging        4
# 4500 mAh Battery with 30W Fast Charging        4
# 4400 mAh Battery with 68W Fast Charging        4
# 3500 mAh Battery with Fast Charging            4
# 4300 mAh Battery with 66W Fast Charging        4
# 4800 mAh Battery with 100W Fast Charging       4
# 5160 mAh Battery with 45W Fast Charging        4
# 5100 mAh Battery with 67W Fast Charging        4
# 4352 mAh Battery with Fast Charging            4
# 4500 mAh Battery with 66W Fast Charging        4
# 6000 mAh Battery with 20W Fast Charging        3
# 5160 mAh Battery with 33W Fast Charging        3
# 6000 mAh Battery with Fast Charging            3
# 4000 mAh Battery with 45W Fast Charging        3
# 4000 mAh Battery with 15W Fast Charging        3
# 4350 mAh Battery with 120W Fast Charging       3
# 5050 mAh Battery with 30W Fast Charging        3
# 3349 mAh Battery with Fast Charging            3
# 4500 mAh Battery with 150W Fast Charging       3
# 4000 mAh Battery with 18W Fast Charging        3
# 4200 mAh Battery with 33W Fast Charging        3
# 5500 mAh Battery with 100W Fast Charging       3
# 4600 mAh Battery with 125W Fast Charging       3
# 3900 mAh Battery with 25W Fast Charging        3
# 4000 mAh Battery with 66W Fast Charging        3
# 4030 mAh Battery                               3
# 3095 mAh Battery with Fast Charging            3
# 4410 mAh Battery with Fast Charging            3
# 3200 mAh Battery with Fast Charging            3
# 3274 mAh Battery with Fast Charging            3
# 5500 mAh Battery with 120W Fast Charging       3
# 4500 mAh Battery with 100W Fast Charging       3
# 4800 mAh Battery with 80W Fast Charging        3
# 4300 mAh Battery with 65W Fast Charging        3
# 4422 mAh Battery with Fast Charging            3
# 3110 mAh Battery                               3
# 4383 mAh Battery with Fast Charging            3
# 4880 mAh Battery with 120W Fast Charging       3
# 4050 mAh Battery with 40W Fast Charging        2
# 3360 mAh Battery                               2
# 4610 mAh Battery with 125W Fast Charging       2
# 3100 mAh Battery with 15W Fast Charging        2
# 4200 mAh Battery with 40W Fast Charging        2
# 5003 mAh Battery with 30W Fast Charging        2
# 4200 mAh Battery with 65W Fast Charging        2
# 5200 mAh Battery with 210W Fast Charging       2
# 4450 mAh Battery with 125W Fast Charging       2
# 3020 mAh Battery                               2
# 4000 mAh Battery with 21W Fast Charging        2
# 3300 mAh Battery                               2
# 4200 mAh Battery with 55W Fast Charging        2
# 5000 mAh Battery with 165W Fast Charging       2
# 4500 mAh Battery with 50W Fast Charging        2
# 4500 mAh Battery with 18W Fast Charging        2
# 5020 mAh Battery with 67W Fast Charging        2
# 3700 mAh Battery with Fast Charging            2
# 1900 mAh Battery                               2
# 2000 mAh Battery                               2
# 4820 mAh Battery with 120W Fast Charging       2
# 4300 mAh Battery with 25W Fast Charging        2
# 4352 mAh Battery with 25W Fast Charging        2
# 4520 mAh Battery with 67W Fast Charging        2
# 5180 mAh Battery with 10W Fast Charging        2
# 4000 mAh Battery with 10W Fast Charging        2
# 4300 mAh Battery with 120W Fast Charging       2
# 5100 mAh Battery with 18W Fast Charging        2
# 4700 mAh Battery with Fast Charging            2
# 6000 mAh Battery with 45W Fast Charging        2
# 5000 mAh Battery with 240W Fast Charging       2
# 6000 mAh Battery with 35W Fast Charging        2
# 4800 mAh Battery with 25W Fast Charging        2
# 5000 mAh Battery with 135W Fast Charging       2
# 5050 mAh Battery with 18W Fast Charging        2
# 3500 mAh Battery with 18W Fast Charging        2
# 5500 mAh Battery with 90W Fast Charging        2
# 7000 mAh Battery with Fast Charging            2
# 4355 mAh Battery with 30W Fast Charging        2
# 4200 mAh Battery with 30W Fast Charging        2
# 2800 mAh Battery                               2
# 4500 mAh Battery with 180W Fast Charging       2
# 7000 mAh Battery with 18W Fast Charging        2
# 5200 mAh Battery with 33W Fast Charging        2
# 4810 mAh Battery with 120W Fast Charging       2
# 5800 mAh Battery with 33W Fast Charging        2
# 4870 mAh Battery with 120W Fast Charging       2
# 5160 mAh Battery with 120W Fast Charging       2
# 1450 mAh Battery                               2
# 2150 mAh Battery                               2
# 3300 mAh Battery with 15W Fast Charging        2
# 4800 mAh Battery with 44W Fast Charging        2
# 2050 mAh Battery with Fast Charging            2
# 5100 mAh Battery with 120W Fast Charging       2
# 5800 mAh Battery with 35W Fast Charging        2
# 5000 mAh Battery with 90W Fast Charging        2
# 5000 mAh Battery with 35W Fast Charging        2
# 4500 mAh Battery with 125W Fast Charging       2
# 5500 mAh Battery with 65W Fast Charging        2
# 3060 mAh Battery with Fast Charging            2
# 4575 mAh Battery with 30W Fast Charging        2
# 4805 mAh Battery with 67W Fast Charging        2
# 5100 mAh Battery with 40W Fast Charging        2
# 4000 mAh Battery with 27W Fast Charging        2
# 4800 mAh Battery with 120W Fast Charging       2
# 1821 mAh Battery with 18W Fast Charging        2
# 5000 mAh Battery with 88W Fast Charging        2
# 4300 mAh Battery with 45W Fast Charging        2
# 2230 mAh Battery                               1
# 4500 mAh Battery with 68W Fast Charging        1
# 4500 mAh Battery with 20W Fast Charging        1
# 4800 mAh Battery with 125W Fast Charging       1
# 2400 mAh Battery                               1
# 2730 mAh Battery                               1
# 4470 mAh Battery with 18W Fast Charging        1
# 3400 mAh Battery with Fast Charging            1
# 4500 mAh Battery with 55W Fast Charging        1
# 4800 mAh Battery with 33W Fast Charging        1
# 4300 mAh Battery with Fast Charging            1
# 3730 mAh Battery with Fast Charging            1
# 9800 mAh Battery with 66W Fast Charging        1
# 4700 mAh Battery with 100W Fast Charging       1
# 5600 mAh Battery with 68W Fast Charging        1
# 4300 mAh Battery with 67W Fast Charging        1
# 5050 mAh Battery with 10W Fast Charging        1
# 4300 mAh Battery with 210W Fast Charging       1
# 4080 mAh Battery with 18W Fast Charging        1
# 5000 mAh Battery with 60W Fast Charging        1
# 3520 mAh Battery with Fast Charging            1
# 3334 mAh Battery with Fast Charging            1
# 5180 mAh Battery with 90W Fast Charging        1
# 4730 mAh Battery with 80W Fast Charging        1
# 4700 mAh Battery with 33W Fast Charging        1
# 5000 mAh Battery with 19W Fast Charging        1
# 8000 mAh Battery                               1
# 2275 mAh Battery                               1
# 5100 mAh Battery with 65W Fast Charging        1
# 4015 mAh Battery with 30W Fast Charging        1
# 4310 mAh Battery with 30W Fast Charging        1
# 5200 mAh Battery with 120W Fast Charging       1
# 5000 mAh Battery with 40W Fast Charging        1
# 7000 mAh Battery                               1
# 22000 mAh Battery with 33W Fast Charging       1
# 4100 mAh Battery                               1
# 3200 mAh Battery                               1
# 3700 mAh Battery with 18W Fast Charging        1
# 5020 mAh Battery with 22.5W Fast Charging      1
# 3600 mAh Battery with 18W Fast Charging        1
# 4800 mAh Battery                               1
# 5050 mAh Battery                               1
# 2500 mAh Battery                               1
# 5080 mAh Battery with 120W Fast Charging       1
# 4532 mAh Battery with Fast Charging            1
# 3315 mAh Battery                               1
# 3000 mAh Battery with 10W Fast Charging        1
# 4350 mAh Battery with 65W Fast Charging        1
# 5065 mAh Battery with 67W Fast Charging        1
# 4620 mAh Battery with 18W Fast Charging        1
# 4860 mAh Battery with 67W Fast Charging        1
# 4000 mAh Battery with 22.5W Fast Charging      1
# 4200 mAh Battery with 67W Fast Charging        1
# 4830 mAh Battery with 67W Fast Charging        1
# 4000 mAh Battery with 20W Fast Charging        1
# 4100 mAh Battery with 33W Fast Charging        1
# 4000 mAh Battery with 30W Fast Charging        1
# 4360 mAh Battery with 66W Fast Charging        1
# 3285 mAh Battery with Fast Charging            1
# 4020 mAh Battery with 68W Fast Charging        1
# 4780 mAh Battery with 30W Fast Charging        1
# 5200 mAh Battery with Fast Charging            1
# 4400 mAh Battery with 44W Fast Charging        1
# 4614 mAh Battery with 30W Fast Charging        1
# 4385 mAh Battery with 18W Fast Charging        1
# 4500 mAh Battery with 22.5W Fast Charging      1
# 4290 mAh Battery with Fast Charging            1
# 5200 mAh Battery                               1
# 5200 mAh Battery with 150W Fast Charging       1
# 4800 mAh Battery with 18W Fast Charging        1
# 5000 mAh Battery with 125W Fast Charging       1
# 5000 mAh Battery with 250W Fast Charging       1
# 5100 mAh Battery with 66W Fast Charging        1
# 6000 mAh Battery with 120W Fast Charging       1
# 4600 mAh Battery with 150W Fast Charging       1
# 4110 mAh Battery with Fast Charging            1
# 9600 mAh Battery with 66W Fast Charging        1
# 4200 mAh Battery with Fast Charging            1
# 4300 mAh Battery with 51W Fast Charging        1
# 5580 mAh Battery with 180W Fast Charging       1
# 5300 mAh Battery with 35W Fast Charging        1
# 3700 mAh Battery with 20W Fast Charging        1
# 4050 mAh Battery with 18W Fast Charging        1
# 5400 mAh Battery with 150W Fast Charging       1
# 4800 mAh Battery with 200W Fast Charging       1
# 5050 mAh Battery with 66W Fast Charging        1
# 5800 mAh Battery with 66W Fast Charging        1
# 2500 mAh Battery with Fast Charging            1
# 3500 mAh Battery with 65W Fast Charging        1
# 4820 mAh Battery with 200W Fast Charging       1
# 4870 mAh Battery with 200W Fast Charging       1
# 5000 mAh Battery with 260W Fast Charging       1
# 2750 mAh Battery with Fast Charging            1
# 3800 mAh Battery with 30W Fast Charging        1
# 6000 mAh Battery with 67W Fast Charging        1
# 4880 mAh Battery with 80W Fast Charging        1
# 6700 mAh Battery with 180W Fast Charging       1
# 11000 mAh Battery with 120W Fast Charging      1
# 10800 mAh Battery with 33W Fast Charging       1
# 4610 mAh Battery with 90W Fast Charging        1
# 4500 mAh Battery                               1
# 21000 mAh Battery with 33W Fast Charging       1
# 4200 mAh Battery with 66W Fast Charging        1
# 4100 mAh Battery with 15W Fast Charging        1
# 2800 mAh Battery with Fast Charging            1
# 4300 mAh Battery with 33W Fast Charging        1
# 5100 mAh Battery with 45W Fast Charging        1
# 6500 mAh Battery with 80W Fast Charging        1
# 5100 mAh Battery with 100W Fast Charging       1
# 4450 mAh Battery                               1
# 2438 mAh Battery with Fast Charging            1
# 4700 mAh Battery with 200W Fast Charging       1
# 4815 mAh Battery with 88W Fast Charging        1
# 4200 mAh Battery with 120W Fast Charging       1
# 5200 mAh Battery with 67W Fast Charging        1
# 5240 mAh Battery with 150W Fast Charging       1
# 4600 mAh Battery with 30W Fast Charging        1
# 4800 mAh Battery with 68W Fast Charging        1
# 4310 mAh Battery with 50W Fast Charging        1
# 7000 mAh Battery with 35W Fast Charging        1
# 4900 mAh Battery with 45W Fast Charging        1
# 6000 mAh Battery with 165W Fast Charging       1
# 4800 mAh Battery with 65W Fast Charging        1
# 5800 mAh Battery with 100W Fast Charging       1
# 5500 mAh Battery with 165W Fast Charging       1
# 4821 mAh Battery with 30W Fast Charging        1
# 5000 mAh Battery with 21W Fast Charging        1
# 7100 mAh Battery with 20W Fast Charging        1
# 7000 mAh Battery with 120W Fast Charging       1
# 4800 mAh Battery with Fast Charging            1
# 4800 mAh Battery with 250W Fast Charging       1
# 5000 mAh Battery with 68.2W Fast Charging      1
# Name: count, dtype: int64
# ############# column end #############
#
# display
# 6.67 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole          113
# 6.7 inches, 1080 x 2412 px, 120 Hz Display with Punch Hole            61
# 6.5 inches, 720 x 1600 px Display with Water Drop Notch               55
# 6.78 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           36
# 6.52 inches, 720 x 1600 px Display with Water Drop Notch              34
# 6.43 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole            34
# 6.51 inches, 720 x 1600 px Display with Water Drop Notch              31
# 6.5 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             30
# 6.43 inches, 1080 x 2400 px Display with Punch Hole                   23
# 6.62 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           23
# 6.55 inches, 1080 x 2400 px, 120 Hz Display with Punch Hole           22
# 6.4 inches, 1080 x 2400 px, 90 Hz Display with Punch Hole             21
# 6.7 inches, 1440 x 3216 px, 120 Hz Display with Punch Hole            21
# ...
# 50 MP + 13 MP + 2 MP Triple Rear & 32 MP + 16 MP Dual Front Camera          1
# 13 MP Rear & 7 MP Front Camera                                              1
# 64 MP + 20 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 12 MP Quad Rear & 12 MP Front Camera                                        1
# 64 MP + 20 MP + 2 MP Triple Rear & Main Front Camera                        1
# 13 MP + Depth Sensor + Ultra Wide Triple Rear & 8 MP Front Camera           1
# 50 MP + 48 MP + 48 MP Triple Rear & 32 MP Front Camera                      1
# 48 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                        1
# 48 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 48 MP + 8 MP + 5 MP Triple Rear & 8 MP Front Camera                         1
# 108 MP + 64 MP + 16 MP Triple Rear & 32 MP Front Camera                     1
# 64 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 13 MP Rear & 2.1 MP Front Camera                                            1
# 24 MP + 10 MP + 5 MP Triple Rear & 24 MP Front Camera                       1
# 64 MP + 13 MP Dual Rear & 16 MP Front Camera                                1
# 64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 50 MP + 13 MP + 8 MP Triple Rear & 48 MP + 8 MP Dual Front Camera           1
# 50 MP + 48 MP + 13 MP Triple Rear & 13 MP Front Camera                      1
# 16 MP + 13 MP + 13 MP Triple Rear & 8 MP Front Camera                       1
# 48 MP Triple Rear & 8 MP Front Camera                                       1
# 50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera                           1
# 108 MP + 8 MP + 8 MP Triple Rear & 16 MP Front Camera                       1
# 24 MP + 8 MP + 5 MP Triple Rear & 24 MP Front Camera                        1
# 12 MP Quad Rear & 8 MP Front Camera                                         1
# 16 MP + 12 MP + 12 MP Triple Rear & 10 MP Front Camera                      1
# 48 MP Quad Rear Camera                                                      1
# 13 MP Rear & 16 MP Front Camera                                             1
# 50 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 200 MP + 50 MP + 8 MP Triple Rear & 50 MP Front Camera                      1
# 50 MP + 8 MP Dual Rear & 10.1 MP Front Camera                               1
# 50 MP + 50 MP + 50 MP Triple Rear & 20 MP Front Camera                      1
# 50 MP Quad Rear & 32 MP Dual Front Camera                                   1
# 13 MP + 2 MP Dual Rear & 20 MP Front Camera                                 1
# 12 MP + 12 MP Dual Rear & 8 MP Front Camera                                 1
# 13 MP + 2 MP Triple Rear & 8 MP Front Camera                                1
# 13 MP Rear & 13 MP Front Camera                                             1
# 47.2 MP + 1.9 MP Dual Rear & 12.6 MP Front Camera                           1
# 50 MP Quad Rear & 48 MP + 8 MP Dual Front Camera                            1
# 48 MP + 12.2 MP + 12.2 MP Triple Rear & 16 MP Front Camera                  1
# 48 MP + 12 MP + 5 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 8 MP + 2 MP Triple Rear & 60 MP Front Camera                        1
# 50 MP + 13 MP Dual Rear & 16 MP Front Camera                                1
# 50 MP + 3 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 50 MP + 2 MP Triple Rear & 5 MP Front Camera                                1
# 16 MP + 12.2 MP Dual Rear & 8 MP + TOF 3D Dual Front Camera                 1
# 64 MP + 16 MP Dual Rear & 20 MP Front Camera                                1
# 12 MP + 2 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 108 MP + 20 MP + 16 MP Triple Rear & 32 MP Front Camera                     1
# 12 MP + 2 MP Dual Rear & 8 MP Front Camera                                  1
# 13 MP + 8 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 48 MP Quad Rear & 32 MP + 8 MP Dual Front Camera                            1
# 108 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                      1
# 64 MP + 8 MP + 2 MP Triple Rear & 44 MP + 8 MP Dual Front Camera            1
# 50 MP + 20 MP + 12 MP Triple Rear & 13 MP Dual Front Camera                 1
# 64 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP Quad Rear & 13 MP Dual Front Camera                                   1
# 64 MP + 2 MP Triple Rear & 16 MP Front Camera                               1
# 64 MP + 13 MP + 5 MP Triple Rear & 20 MP Front Camera                       1
# 12 MP + 12 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 50 MP + 16 MP + 13 MP Triple Rear & 32 MP Front Camera                      1
# 16 MP Rear & 13 MP Front Camera                                             1
# 13 MP Quad Rear & 8 MP Front Camera                                         1
# 48 MP Quad Rear & 16 MP + 2 MP Dual Front Camera                            1
# 13 MP + 2 MP Dual Rear & 16 MP Front Camera                                 1
# 13 MP + 2 MP Dual Rear & 13 MP Front Camera                                 1
# 108 MP Quad Rear & 20 MP Front Camera                                       1
# 48 MP + 8 MP + 2 MP Triple Rear & 32 MP Front Camera                        1
# 64 MP + 50 MP + 13 MP Triple Rear & 13 MP Front Camera                      1
# 50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Front Camera                     1
# 50 MP + 13 MP Dual Rear & 13 MP Front Camera                                1
# 200 MP Quad Rear & 16 MP Front Camera                                       1
# 5 MP + 0.3 MP Dual Rear & 5 MP Front Camera                                 1
# 50 MP + 50 MP Triple Rear & 16 MP Front Camera                              1
# 5 MP Rear & 5 MP Front Camera                                               1
# 16 MP + 12 MP + 12 MP Triple Rear & 10 MP + 8 MP Dual Front Camera          1
# 50 MP + 12 MP Dual Rear & 32 MP Front Camera                                1
# 64 MP Quad Rear & 44 MP + 8 MP Dual Front Camera                            1
# 108 MP + 100 MP + 2 MP Triple Rear & 32 MP Front Camera                     1
# 50 MP + 32 MP + 12 MP Triple Rear & 50 MP + 2 MP Dual Front Camera          1
# 64 MP + 8 MP Dual Rear & 32 MP Front Camera                                 1
# 48 MP + 48 MP + 12 MP Triple Rear & 12 MP Front Camera                      1
# 50 MP + 50 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 108 MP + 8 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# 50 MP + 50 MP + 32 MP Triple Rear & 12 MP + 12 MP Dual Front Camera         1
# 50 MP + 50 MP + 13 MP Triple Rear & 32 MP + 16 MP Dual Front Camera         1
# 108 MP + 8 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera          1
# 160 MP + 50 MP + 50 MP Triple Rear & 12 MP Front Camera                     1
# 64 MP + 50 MP + Macro Triple Rear & 16 MP Front Camera                      1
# 108 MP + 50 MP + 2 MP Triple Rear & 32 MP Front Camera                      1
# 108 MP + 8 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 200 MP + 32 MP + 8 MP Triple Rear & 32 MP Front Camera                      1
# 13 MP + 12 MP Dual Rear & 32 MP Front Camera                                1
# 64 MP + 64 MP + 50 MP Triple Rear & 16 MP Front Camera                      1
# 50 MP + 48 MP + 12 MP Triple Rear & 13 MP Dual Front Camera                 1
# 50 MP + 50 MP + 32 MP Triple Rear & 12 MP Front Camera                      1
# 108 MP + 2 MP Dual Rear Camera                                              1
# 50 MP + 50 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# 48 MP + 48 MP + 40 MP Triple Rear & 13 MP Front Camera                      1
# 108 MP + 2 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 64 MP + 50 MP + 32 MP Triple Rear & 32 MP Front Camera                      1
# 200 MP + 32 MP + 12 MP Triple Rear & 50 MP + 2 MP Dual Front Camera         1
# 50 MP + 50 MP + 12 MP Triple Rear & 16 MP Front Camera                      1
# 200 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                      1
# 50 MP + 50 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 64 MP + 12 MP + 8 MP Triple Rear & 50 MP Front Camera                       1
# 64 MP + 32 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 64 MP + 50 MP + 48 MP Triple Rear & 32 MP Front Camera                      1
# 108 MP + 2 MP + 0.08 MP Triple Rear & 32 MP Front Camera                    1
# 200 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                     1
# 12 MP Dual Rear & 8 MP Front Camera                                         1
# 64 MP + 50 MP + 50 MP Triple Rear & 16 MP + 12 MP Dual Front Camera         1
# 13 MP + 0.08 MP Dual Rear & 8 MP Front Camera                               1
# 64 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 200 MP + 13 MP + 5 MP Triple Rear & 32 MP Front Camera                      1
# 12.2 MP + 12 MP Dual Rear & 10.1 MP Front Camera                            1
# 64 MP + 50 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 64 MP + 13 MP Dual Rear & 13 MP Front Camera                                1
# 48 MP + 48 MP + 13 MP Triple Rear & 13 MP Front Camera                      1
# 50 MP + 2 MP + 0.08 MP Triple Rear & 32 MP Front Camera                     1
# 50 MP + 13 MP + 5 MP Triple Rear & 16 MP Front Camera                       1
# 200 MP + 32 MP + 5 MP Triple Rear & 32 MP Front Camera                      1
# 50 MP + 50 MP + 12 MP Triple Rear & 50 MP Front Camera                      1
# 50 MP + 50 MP + 8 MP Triple Rear & 16 MP Front Camera                       1
# 16 MP Dual Rear & 8 MP Front Camera                                         1
# 200 MP + 8 MP + 2 MP Triple Rear & 20 MP Front Camera                       1
# 50 MP + 12 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 8 MP Dual Rear & 12 MP Front Camera                                 1
# 108 MP + 64 MP + 64 MP Triple Rear & 16 MP Front Camera                     1
# 48 MP + 8 MP + 8 MP Triple Rear & 8 MP Front Camera                         1
# 48 MP + 10.8 MP + 10.8 MP Triple Rear & 9.5 MP + 8 MP Dual Front Camera     1
# 50 MP + 50 MP + 20 MP Triple Rear & 16 MP Front Camera                      1
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP + 8 MP Dual Front Camera            1
# 13 MP + 0.3 MP Dual Rear & 5 MP Front Camera                                1
# 50 MP + 50 MP + 3 MP Triple Rear & 32 MP Front Camera                       1
# 108 MP + 8 MP + 2 MP Triple Rear & 12 MP Front Camera                       1
# 64 MP + 13 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 108 MP + 50 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera        1
# 64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 50.3 MP + 50 MP + 50 MP Triple Rear & 32 MP Front Camera                    1
# 50 MP + 50 MP + 2 MP Triple Rear & 60 MP Front Camera                       1
# 13 MP + Depth Sensor Dual Rear & 5 MP Front Camera                          1
# 50 MP + 50 MP + 13 MP Triple Rear & 16 MP Front Camera                      1
# 50 MP + 16 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 50 MP + 8 MP + 2 MP Triple Rear & 50 MP + 8 MP Dual Front Camera            1
# 50.3 MP + 50 MP + 12 MP Triple Rear & 32 MP Front Camera                    1
# 54 MP + 8 MP + 2 MP Triple Rear & 16 MP Front Camera                        1
# 200 MP + 13 MP + 2 MP Triple Rear & 60 MP Front Camera                      1
# 200 MP + 12 MP + 12 MP Triple Rear & 32 MP + 32 MP Dual Front Camera        1
# 50 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                        1
# 50 MP + 13 MP + 12 MP Triple Rear & 32 MP Front Camera                      1
# 21 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                         1
# 100 MP + 48 MP + 13 MP Triple Rear & 32 MP Front Camera                     1
# 100 MP + 2 MP + 2 MP Triple Rear & 32 MP Front Camera                       1
# 48 MP + 5 MP Dual Rear & 16 MP Front Camera                                 1
# 108 MP + 5 MP + 2 MP Triple Rear & 8 MP Front Camera                        1
# 50 MP + 50 MP + 32 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         1
# 50 MP + 12 MP Dual Rear & 50 MP Front Camera                                1
# 108 MP + 32 MP + 2 MP Triple Rear & 32 MP Front Camera                      1
# 200 MP + 48 MP + 13 MP Triple Rear & 50 MP Front Camera                     1
# 50 MP + 16 MP + 5 MP Triple Rear & 32 MP Front Camera                       1
# 48 MP Rear & 8 MP Front Camera                                              1
# 50 MP + 8 MP + 2 MP Triple Rear & 32 MP + 32 MP Dual Front Camera           1
# 50 MP Quad Rear & 12 MP Dual Front Camera                                   1
# 50 MP + 13 MP + 8 MP Triple Rear & 32 MP Front Camera                       1
# 50 MP + 48 MP + 2 MP Triple Rear & 16 MP Front Camera                       1
# 108 MP + 5 MP + 2 MP Triple Rear & 50 MP Front Camera                       1
# 64 MP + 50 MP + 50 MP Triple Rear & 32 MP + 32 MP Dual Front Camera         1
# 108 MP + 20 MP + 5 MP Triple Rear & 32 MP Front Camera                      1
# 200 MP + 24 MP + 16 MP Triple Rear & 32 MP Front Camera                     1
# 50 MP + 50 MP + Depth Sensor Triple Rear & 50 MP Front Camera               1
# 50 MP + 50 MP + 10 MP Triple Rear & 32 MP Front Camera                      1
# Name: count, dtype: int64
# ############# column end #############
#
# extra_storage
# Memory Card Not Supported              789
# Memory Card Supported, upto 1 TB       385
# Memory Card (Hybrid), upto 1 TB        214
# Memory Card Supported, upto 512 GB     149
# Memory Card Supported                  148
# Memory Card Supported, upto 256 GB     109
# Memory Card (Hybrid)                    67
# Memory Card Supported, upto 2 TB        35
# Memory Card (Hybrid), upto 256 GB       20
# Memory Card (Hybrid), upto 512 GB       13
# Memory Card Supported, upto 128 GB      11
# Memory Card Supported, upto 32 GB        8
# Memory Card (Hybrid), upto 2 TB          5
# Memory Card (Hybrid), upto 128 GB        5
# Memory Card (Hybrid), upto 64 GB         3
# Memory Card Supported, upto 1000 GB      2
# Name: count, dtype: int64
# ############# column end #############
#
# os
# Android v12                        623
# Android v13                        514
# Android v11                        375
# Android v14                        116
# Android v10                         82
# Android v9.0 (Pie)                  38
# Android v10.0                       29
# iOS v16                             20
# iOS v15                             18
# iOS v17                             14
# Android v8.1 (Oreo)                 12
# Android v15                         10
# iOS v14                              8
# iOS v13                              7
# Android v11.0                        5
# Android v12.1                        4
# iOS v18                              4
# Android v8.0 (Oreo)                  4
# iOS v15.0                            3
# Hongmeng OS v4.0                     3
# iOS v13.0                            3
# Flyme 10                             3
# Bluetooth                            2
# iOS v12.3                            2
# iOS v14.0                            2
# Android v5.1 (Lollipop)              2
# HarmonyOS v2                         2
# EMUI v12                             2
# Android v5.1.1 (Lollipop)            2
# Android v6.0 (Marshmallow)           2
# HarmonyOS v2.0                       2
# Harmony v2.0                         2
# Android                              1
# Android v7.1 (Nougat)                1
# HarmonyOS                            1
# Android v4.4.2 (KitKat)              1
# iOS v10                              1
# Pragati OS (Powered by Android)      1
# Hongmeng OS v3.0                     1
# iOS v20                              1
# iOS v19                              1
# HarmonyOS v4                         1
# HarmonyOS v3.1                       1
# Android v9 (Pie)                     1
# Name: count, dtype: int64
# ############# column end #############

# %% [markdown]
# **Here we have completed our basic cleaning means now each column has its info only not of any other columns info.**

# %%
df1.to_csv('mobiles_cleaned_version1.csv',index=False)
